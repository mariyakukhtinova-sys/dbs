# %% [markdown]
# # Выборка и агрегация данных в MongoDB
#
# ###Цель домашней работы
#
# Закрепить на практике основные приемы работы с СУБД MongoDB, включая выборку, сортировку, объединение, агрегацию данных и передачу результатов выборки в программу на Python в целях аналитики и дальнейшей обработки.

# %% [markdown]
# ### Условия выполнения задания
#
# В этом задании вам предстоит выполнить несколько запросов к базе данных для получения выборок по условиям, а также воспользоваться фреймворком агрегации MongoDB для построения конвейера обработки данных.
#
# **Максимальное количество баллов за выполнение домашней работы:** 10.

# %% [markdown]
# ##Как выполнять задание
#
# В работе над заданием нужно использовать следующие инструменты:
#
# * **MongoDB:**
#
# 1. Зарегистрируйтесь в сервисе MongoDB Atlas: https://www.mongodb.com/atlas/database.
# 1. Создайте кластер уровня M0 — это бесплатно.
# 1. Добавьте в кластер тестовую базу данных `sample_mflix`, используя опцию Load Sample Dataset.
#
# В качестве альтернативы вы можете установить MongoDB на свой локальный компьютер и импортировать необходимые датасеты в свою СУБД, загрузив их по ссылке: https://github.com/neelabalan/mongodb-sample-dataset/tree/main/sample_mflix. Для этого подключитесь к своему серверу через Compass, создайте новую БД, создайте для каждого датасета коллекцию и щелкните Add data → Import JSON or CSV file.
#
# * **MongoDB Compass** — графический интерфейс для работы с MongoDB, который можно использовать как вспомогательный инструмент при создании запросов и построении агрегаций.
#
# * **Python и библиотека PyMongo.** Работайте в Jupyter Notebook или Google Colaboratory. Рекомендуется использовать версию Python 3.12.

# %% [markdown]
# ##Формат сдачи
#
# Результаты работы необходимо оформить в виде ноутбука Jupyter. Можно загрузить файл в LMS либо поделиться ссылкой на Google Colaboratory.

# %% [markdown]
# ##Место, где нужно выполнить задание

# %%
#Начать выполнение задания тут

# %%
#!pip install pymongo

import pymongo

client = pymongo.MongoClient("mongodb+srv://<ПОЛЬЗОВАТЕЛЬ>:<ПАРОЛЬ>@<АДРЕС КЛАСТЕРА>")
print(client.list_database_names())  # Вывести список БД для проверки подключения
# Out:
# Requirement already satisfied: pymongo in /Users/maria/anaconda3/lib/python3.11/site-packages (4.15.4)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/maria/anaconda3/lib/python3.11/site-packages (from pymongo) (2.8.0)
# ['sample_airbnb', 'sample_analytics', 'sample_geospatial', 'sample_guides', 'sample_mflix', 'sample_restaurants', 'sample_supplies', 'sample_training', 'sample_weatherdata', 'admin', 'local']

# %% [markdown]
# ### Упражнение 1. Запросы на выборку

# %% [markdown]
# Цель этого упражнения — закрепить навык выполнения запросов на выборку. Все запросы выполняются на базе `sample_mflix` с данными о кинофильмах.

# %% [markdown]
# #### Задача 1.1 (1 балл)

# %% [markdown]
# Выведите из коллекции `theaters` документы о кинотеатрах в городе Florence, штат KY.
#
# **Для справки:**
#
# * Обратите внимание, что информация об адресе кинотеатров хранится во вложенных документах. Для доступа к полям вложенных документов следует использовать точку: `родительский_документ.вложенный_документ.поле`.
# * В случае затруднений с написанием логического условия обращайтесь к сопоставлению синтаксиса SQL и Mongo: https://www.mongodb.com/docs/manual/reference/sql-comparison/.
# * Если вы предпочитаете сперва выполнять запросы в Compass, из этого приложения можно выгружать код готового запроса на Python (кнопка с символом `</>`).

# %%
# Ваш код здесь
db = client.sample_mflix
collection = db.theaters
list(
    collection.find({'$and' : [{'location.address.city': 'Florence'}, {'location.address.state': 'KY'} ]})
    )
# Out:
# [{'_id': ObjectId('59a47287cfa9a3a73e51e893'),
#   'theaterId': 161,
#   'location': {'address': {'street1': '100 Meijer Dr.',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.636383, 39.014843]}}},
#  {'_id': ObjectId('59a47287cfa9a3a73e51ea02'),
#   'theaterId': 2823,
#   'location': {'address': {'street1': '2823 Florence Mall',
#     'street2': '#2148',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.6499595, 38.9967246]}}}]

# %% [markdown]
# #### Задача 1.2 (1 балл)

# %% [markdown]
# Сделайте запрос к коллекции `comments` и выведите один комментарий (значение поля `text`) пользователя по имени Doreah.

# %%
# Ваш код здесь
list(
    db.comments.find({'name' : 'Doreah'},{'_id': 0, 'text': 1})
    )
# Out:
# [{'text': 'Porro explicabo cumque vitae sint quia quis. Consequuntur voluptatibus optio maxime ratione temporibus incidunt minus architecto.'},
#  {'text': 'Nulla assumenda corporis a impedit. Ratione voluptates veritatis dolorem quod officiis minima. Labore dolor repudiandae voluptatum nam. Dignissimos quo sit sint sint labore similique.'},
#  {'text': 'Perspiciatis error id officia reiciendis. Voluptas alias magni amet velit. Nam sapiente at sequi non eaque ex.'},
#  {'text': 'Impedit mollitia quam hic modi. Incidunt et impedit esse sequi. Provident porro modi corporis reprehenderit.'},
#  {'text': 'Perferendis soluta nisi nisi dignissimos at voluptates cumque. Molestias nihil id consectetur iste. Soluta repellendus magni tempora aperiam. Expedita iusto adipisci nam maxime deleniti.'},
#  {'text': 'Libero magni ipsam sint reiciendis neque. Recusandae consequatur accusantium dignissimos doloribus aspernatur.'},
#  {'text': 'Nisi porro ad libero temporibus enim quas suscipit. Dolorem corporis magni cum natus nesciunt. Facere laborum quam minima. Nulla dignissimos consectetur perferendis fuga animi.'},
#  {'text': 'Id provident odio numquam perferendis. Dolores eum itaque aspernatur voluptatem quasi sint maiores. Quam culpa porro debitis quisquam modi quisquam deleniti.'},
#  {'text': 'Commodi accusamus totam eaque sunt. Nihil reiciendis commodi molestiae esse ipsam corporis reprehenderit. Non nam similique vel dolor magni quia quis.'},
#  {'text': 'Impedit libero facilis quae placeat. Corrupti quis minima sunt. Fuga numquam fugit asperiores sint vitae repudiandae.'},
#  {'text': 'Tempore dolores natus accusamus reiciendis. Impedit consequuntur vel labore perferendis maiores est. Quas sint at repudiandae nihil eum.'},
#  {'text': 'Praesentium deserunt modi ad minus. Facere id similique perspiciatis qui sequi inventore. Itaque sunt non deleniti veniam ipsa. Reprehenderit fuga officia id fugiat commodi rem.'},
#  {'text': 'Sed optio excepturi recusandae. Vitae saepe sed aliquid facilis dolor quam nesciunt. Voluptates perferendis excepturi illum debitis reiciendis alias.'},
#  {'text': 'Iure doloremque officia fuga mollitia labore nam. Quasi neque repellendus debitis officiis. Quia ea eum mollitia occaecati aliquam error laborum. Repellendus corrupti cum nostrum officiis corporis.'},
#  {'text': 'Temporibus laborum minus pariatur laborum accusamus facere quasi ut. Quis molestias dicta maiores dolorem maiores. Iusto eveniet adipisci autem. Incidunt nihil nobis corrupti consequatur.'},
#  {'text': 'Animi dolor voluptatem voluptatem autem accusamus voluptate. Architecto provident quidem tempore quibusdam beatae. Harum veritatis perspiciatis ratione eveniet fugit molestiae illum.'},
#  {'text': 'Similique sed placeat accusantium. Qui voluptates corporis placeat sapiente. Adipisci aspernatur culpa nam debitis voluptatum.'},
#  {'text': 'Cum molestiae fugit minus. Atque omnis soluta nesciunt possimus ex molestias atque. Deleniti maxime aut voluptatum occaecati quasi minus voluptates quo.'},
#  {'text': 'Pariatur pariatur adipisci velit voluptatem. Minus dolorem cum repellat. Ab tempora fugiat doloribus sit.'},
#  {'text': 'Quaerat explicabo repellendus debitis laudantium nobis quia. Ipsam perferendis maiores doloremque at mollitia. Autem rem esse qui facilis omnis. Culpa enim doloremque tempore quibusdam quia aut sit.'},
#  {'text': 'Nulla minima excepturi eaque repudiandae rem. Pariatur rerum animi voluptates asperiores nam minima pariatur. Accusantium dolore repellendus modi saepe.'},
#  {'text': 'Fuga suscipit impedit perferendis sapiente laudantium harum magnam. Recusandae corrupti magni deleniti totam. Numquam placeat iste cumque dicta. Est porro numquam quos blanditiis dolore provident.'},
#  {'text': 'Vel doloremque harum magni quae beatae. Blanditiis odit exercitationem sunt. Aut optio reprehenderit magni impedit.'},
#  {'text': 'Iusto accusamus id in voluptatem libero voluptate quisquam in. Eius illo autem est cupiditate amet. Id explicabo hic corrupti. Placeat sapiente debitis odit distinctio id nobis voluptatum.'},
#  {'text': 'Tenetur deleniti dolor repudiandae enim est perferendis eum. Unde natus eveniet corrupti voluptas placeat. Inventore magni neque optio in.'},
#  {'text': 'Necessitatibus ab atque labore earum. Excepturi odio dignissimos nobis magnam libero. Quam perspiciatis facilis et quibusdam adipisci.'},
#  {'text': 'Quae rerum aliquam praesentium provident. Maiores doloribus tenetur et at culpa quasi repudiandae. Molestiae sit maiores pariatur.'},
#  {'text': 'Quidem sequi sequi molestias sequi amet unde ipsam. Culpa cupiditate harum nihil quo recusandae. Aperiam suscipit facilis impedit. Reiciendis deleniti ducimus eos sint a.'},
#  {'text': 'Sunt nobis amet exercitationem. Voluptatem minus distinctio repudiandae libero. Sunt sed consequatur quo aspernatur in voluptate. Facilis cumque vitae voluptates praesentium.'},
#  {'text': 'Voluptas quae repudiandae sunt. Ad rem nisi quam accusantium exercitationem. Optio sed aliquid vero.'},
#  {'text': 'Porro cupiditate laborum praesentium modi quisquam doloribus dolorum. Repudiandae vero quos beatae dignissimos vel.'},
#  {'text': 'Soluta voluptate autem natus inventore nihil odio temporibus. Accusamus eius eius illum illum velit.'},
#  {'text': 'Doloremque maiores beatae magnam dolores vel. Animi perferendis laborum ducimus quas voluptatum quod. Asperiores illum reprehenderit commodi porro nulla iure.'},
#  {'text': 'Magnam officia ex repellendus labore. Excepturi officia dolore debitis eius dolores officia. Modi nulla porro laborum.'},
#  {'text': 'Alias mollitia dicta laboriosam eum. Reiciendis ut accusantium eaque quos debitis quam eligendi. Saepe fugiat non sit voluptate. Aliquid recusandae rem veritatis similique distinctio.'},
#  {'text': 'Maiores temporibus exercitationem magni quidem asperiores repudiandae voluptatem. Assumenda nisi quos necessitatibus odio eius. At labore illo fugiat cum inventore.'},
#  {'text': 'Inventore sit ea dolorem repudiandae. Dignissimos esse animi sit eligendi minus.'},
#  {'text': 'Laborum impedit officia asperiores enim eius perferendis. Autem aliquid corporis voluptas porro quaerat quas praesentium. Quas voluptatum quis placeat dignissimos fuga corporis excepturi.'},
#  {'text': 'Nemo repudiandae accusamus autem ut quisquam vel ipsum. Ratione non commodi nisi neque. Quisquam labore voluptas architecto ratione voluptatem voluptatibus fuga.'},
#  {'text': 'Optio deleniti ducimus quis ipsum consectetur officia. Cumque eum odio fugit perferendis nobis natus. Ipsa nobis officia facilis ipsa.'},
#  {'text': 'Assumenda quisquam animi adipisci natus architecto rerum veniam. Quas libero corrupti laudantium repellendus dignissimos nulla. Animi at expedita corporis debitis necessitatibus dolorem quos.'},
#  {'text': 'Odit quis excepturi minus necessitatibus sit occaecati iusto. Iure fuga fugiat ipsa odit. Impedit sunt debitis a tempore. Excepturi quibusdam laboriosam consequatur eum quas.'},
#  {'text': 'Nobis sint debitis nesciunt quod adipisci. Non porro placeat excepturi vel blanditiis nostrum eaque. Eligendi enim accusantium molestiae aliquid sint.'},
#  {'text': 'Eligendi doloremque omnis eius aliquam sunt repudiandae reiciendis. Aliquam adipisci quam fuga assumenda doloremque voluptate.'},
#  {'text': 'Debitis vel labore officiis. Incidunt repudiandae totam voluptatibus asperiores aut eos. Consequuntur quo sit necessitatibus dolore odio laboriosam delectus sapiente.'},
#  {'text': 'Perferendis fugiat quos hic voluptatibus fugit beatae voluptatum. Repellat facilis commodi quod et molestiae sequi eos alias. Culpa inventore mollitia porro impedit et.'},
#  {'text': 'Voluptatum laborum voluptatum tempora sed. Labore ea sed cumque vero doloribus in. Reiciendis corrupti deserunt impedit voluptate dolorem nulla accusantium voluptas.'},
#  {'text': 'Blanditiis nesciunt excepturi repudiandae voluptates deleniti delectus ea. Mollitia architecto recusandae laborum nobis. Soluta exercitationem totam impedit nam soluta at.'},
#  {'text': 'Consequuntur deleniti nobis vero libero suscipit consectetur. A maiores dolores iste repellat autem. Ut architecto debitis maiores numquam facere voluptatum architecto.'},
#  {'text': 'Quo officia repellat iste quidem vel. Temporibus laudantium eius veniam temporibus. Dolores nisi optio veritatis magni optio odit. Minima quidem optio fugiat quas similique.'},
#  {'text': 'Dolor aut earum veritatis aliquam reiciendis. Numquam quod qui consectetur asperiores ipsum.'},
#  {'text': 'Veritatis maxime quisquam excepturi cumque. Excepturi temporibus architecto aut culpa incidunt delectus. Nobis aliquam facere nisi iure enim harum.'},
#  {'text': 'Quia illum quo labore molestias. Perferendis quis atque laborum corrupti. Inventore veritatis voluptates magnam debitis voluptatum nobis eveniet. Consequuntur iste corporis voluptas.'},
#  {'text': 'Inventore quo quod totam alias expedita amet. Fugiat eaque quas rem impedit itaque. Eveniet omnis nostrum nostrum nam error enim.'},
#  {'text': 'Quia incidunt iusto non consectetur. Eaque facilis ipsa accusamus ratione quod tempora. Rerum a aspernatur assumenda suscipit rerum.'},
#  {'text': 'Sunt quas rem labore iusto iste laborum consequuntur. Sit dolor ratione eveniet aliquid iure fugiat id quia.'},
#  {'text': 'Quaerat velit dolore saepe officia repudiandae. Officia saepe dolorum nobis harum. Nemo veniam incidunt voluptatem repudiandae sint. Ex repudiandae assumenda illo quis rerum.'},
#  {'text': 'Neque rem esse quas ipsa ullam animi. Fugiat voluptatem veritatis modi. Ea aliquid id pariatur. Mollitia tempore reprehenderit magnam corporis aperiam.'},
#  {'text': 'Aliquid incidunt beatae dolore blanditiis exercitationem est quisquam. Earum fugit rerum quis iusto explicabo nemo saepe porro. Quia necessitatibus dolorum quos quod.'},
#  {'text': 'Quasi officia repellat earum alias expedita. Aspernatur exercitationem inventore temporibus cum repudiandae ad architecto.'},
#  {'text': 'Hic non animi magni delectus. Eius totam esse a id consequuntur labore fuga. Provident officiis odio molestias tenetur dignissimos placeat perspiciatis.'},
#  {'text': 'Incidunt deleniti natus reprehenderit quos magnam. Commodi minus eveniet ea fuga. Facere sed molestiae aliquid quidem. Saepe dicta eveniet quia consectetur accusamus reiciendis.'},
#  {'text': 'Aspernatur numquam fuga illo voluptate ab neque doloribus. Doloribus iste fugit fugiat sint ea. Non temporibus esse blanditiis suscipit possimus sequi doloremque.'},
#  {'text': 'Ullam quia aperiam vitae dicta illum aspernatur. Ratione nostrum porro laboriosam. Ipsam nulla amet temporibus optio. Sequi neque sint laboriosam iure expedita totam natus.'},
#  {'text': 'Doloribus velit fuga rem eius vitae dolorem. Quaerat facilis nulla saepe. Officiis est architecto a itaque totam deleniti quaerat.'},
#  {'text': 'Nisi totam omnis assumenda sapiente. Quos facilis id et aliquam corporis fugit. Nesciunt atque eaque dolorum facere similique.'},
#  {'text': 'Aperiam doloremque hic labore aspernatur culpa. Fuga quas id sint illum natus sed voluptates occaecati. Fugiat debitis pariatur optio accusantium. Ab ipsam accusamus similique distinctio.'},
#  {'text': 'Minus officiis reprehenderit quod similique quis assumenda. Praesentium corporis nemo nisi eaque sint dolorem a. Dolor perferendis nemo laboriosam vero minus et.'},
#  {'text': 'Quo non reprehenderit fugit necessitatibus fugiat. Sit delectus rerum laboriosam totam fugit nobis dolores. Cumque quos voluptatum reprehenderit nobis explicabo suscipit doloremque.'},
#  {'text': 'Iste provident iste fugit blanditiis unde maiores suscipit harum. Est quos incidunt similique voluptate.'},
#  {'text': 'Veniam illo incidunt temporibus distinctio placeat earum. Id nostrum beatae repellendus magnam voluptas fugit laboriosam. Maiores amet sequi ipsa quod. Iusto ut doloribus rem quo.'},
#  {'text': 'Odit occaecati culpa recusandae quo nihil nesciunt. At delectus ullam dolorum perspiciatis delectus ipsam aperiam. Et corporis sapiente at a doloremque.'},
#  {'text': 'Dolor debitis itaque officia beatae. Ea non dicta a error et eligendi. Rerum nulla eveniet similique non aliquid aut dolorum.'},
#  {'text': 'Modi hic sapiente consectetur aspernatur. Dolorum ab quae porro error enim. At possimus accusantium dolore.'},
#  {'text': 'Ducimus corporis autem ducimus magni quis perferendis. Ipsa necessitatibus at debitis. Minima praesentium cum atque beatae blanditiis cum tenetur.'},
#  {'text': 'Consequuntur cupiditate architecto accusantium quisquam earum est repellat. Aut reiciendis atque accusamus quis. Labore rerum excepturi quisquam dicta.'},
#  {'text': 'Dolorum odio culpa dignissimos libero accusantium quo possimus. Possimus ipsa optio laboriosam incidunt quia porro.'},
#  {'text': 'Adipisci quis nesciunt quaerat tempore. Odio voluptatum nostrum saepe explicabo tempore dolores quibusdam facere. Quaerat exercitationem voluptates vel rem corporis doloremque in.'},
#  {'text': 'Inventore voluptatibus enim laudantium ducimus fugiat accusantium. Labore vero eum doloribus quaerat esse repudiandae eius.'},
#  {'text': 'Iure aperiam quod fugit ea iure dolores cupiditate. Voluptatibus quidem facilis minima necessitatibus sequi deleniti. Ab ad fugiat odit occaecati beatae.'},
#  {'text': 'Natus dolore velit laudantium inventore. Sit quidem atque optio consequatur aspernatur. At dignissimos praesentium explicabo tempora accusantium nulla ipsa.'},
#  {'text': 'Fugiat voluptatem iusto in provident aperiam earum. Voluptatum inventore nobis perferendis est asperiores. Iusto id ut cum sit blanditiis.'},
#  {'text': 'Quis deserunt esse laboriosam quas accusantium dolore. Suscipit quidem et delectus.'},
#  {'text': 'Quam dolore sed dolor. Atque commodi cumque aut quas tenetur. Sunt molestiae in ea ad praesentium fuga at.\nCorrupti quo hic natus dolorum a iure tempore. Consectetur numquam amet non deleniti.'},
#  {'text': 'Et ab itaque quis veniam nihil. Aspernatur eveniet voluptate recusandae. Itaque ea officiis delectus inventore quidem. Placeat debitis minus tempora veniam.'},
#  {'text': 'Molestias sint aliquid aliquam non. Architecto cupiditate id laudantium earum. Ullam reprehenderit iste voluptate occaecati porro dolorum odit consequuntur.'},
#  {'text': 'Provident beatae veniam porro aliquid distinctio. Officiis corrupti aliquid ea eligendi delectus. Nemo porro eaque vel quaerat corporis corporis.'},
#  {'text': 'Iste repellat fuga facilis. Corporis culpa asperiores quia magni. Voluptatem natus repellendus a quo tempora.'},
#  {'text': 'At voluptas delectus earum odio. Voluptatem rerum nam veniam quis maiores libero. Nihil ea rerum consequuntur quis consectetur magni. Quisquam a iure reprehenderit ut quasi.'},
#  {'text': 'Recusandae consequatur amet dolorum ab quisquam perferendis. Debitis corporis quia quo ducimus modi enim. Vero harum reiciendis laborum repellendus corporis dolorem.'},
#  {'text': 'Minima porro recusandae eligendi voluptates accusamus dolores. Suscipit corrupti distinctio dicta error nulla. Eius cumque ipsa eveniet id officia deserunt dolore. Doloremque ipsa debitis id veniam.'},
#  {'text': 'Officiis debitis fuga illo occaecati illo quisquam. Accusantium vel ipsa in doloribus nesciunt optio explicabo. Officiis at voluptate officiis est doloremque voluptatibus quasi facere.'},
#  {'text': 'Mollitia porro nam voluptas provident inventore. Sunt maxime beatae pariatur necessitatibus rerum veniam nobis quam. Fuga asperiores tenetur reiciendis sint.'},
#  {'text': 'Soluta sint asperiores blanditiis repellendus. Explicabo possimus cum in animi voluptatem corporis facere. Possimus sed distinctio dolores saepe.'},
#  {'text': 'Natus laboriosam blanditiis ipsa similique perferendis necessitatibus. Culpa fugiat quibusdam dolorum quasi amet. Ut distinctio dolores corporis nam ut dolorem dolores at.'},
#  {'text': 'Id nesciunt nobis neque atque qui cupiditate. Impedit dolores nulla molestias quam magnam dolorem esse blanditiis. Tempora dolorum odio unde cupiditate error.'},
#  {'text': 'Odit esse quo cumque numquam voluptatem nesciunt. Odit suscipit maxime maxime sunt laborum laboriosam accusantium praesentium.'},
#  {'text': 'Provident dolores dicta ipsam earum vitae possimus unde. Suscipit vel quisquam facere nesciunt eius. Optio dolor debitis ullam.'},
#  {'text': 'Quisquam voluptas id id ipsum expedita sunt accusamus. Aperiam eveniet deserunt similique. Occaecati non totam ratione commodi perspiciatis voluptas assumenda dolore. Nemo id quae sapiente.'},
#  {'text': 'Dolores officiis eum tempora eaque. Consequatur sunt quaerat quibusdam amet perspiciatis laborum. Libero quidem eius voluptatum dicta consequatur beatae.'},
#  {'text': 'Et incidunt in velit cupiditate perferendis. Quo rem eum vero. A quod illo facere architecto ex repudiandae quasi.'},
#  {'text': 'Ea quidem dolor provident nesciunt. Totam atque atque voluptate quisquam.'},
#  {'text': 'Animi esse impedit sapiente quas qui in. Nihil earum aut suscipit. Tempora saepe officiis nobis dicta perferendis rem voluptates.'},
#  {'text': 'Omnis cupiditate corrupti exercitationem. Consectetur sapiente enim earum quaerat. Ad accusantium repudiandae quae doloribus enim vel. Ullam assumenda quasi dolores praesentium odit excepturi.'},
#  {'text': 'Provident veniam provident totam saepe. Pariatur quidem ea amet quia. Eum officia eaque recusandae error omnis doloribus porro.'},
#  {'text': 'Sed repudiandae quisquam dolore enim dolores eligendi. Minima labore libero commodi eius consequuntur. Laborum dolore minima itaque ipsam voluptate. Tempora veritatis soluta tempore ducimus.'},
#  {'text': 'Optio perspiciatis eaque quod esse. Rem tempora nemo molestiae labore assumenda quia tenetur. Porro consequatur ipsum iste autem sequi delectus id. Perspiciatis molestias natus suscipit numquam.'},
#  {'text': 'Dolorem fuga eius eum possimus. Nemo perspiciatis ea unde mollitia eius illo. Dicta itaque odit suscipit pariatur repellat.'},
#  {'text': 'Veniam nihil quaerat corporis. Velit odio error ipsa voluptate. Voluptatibus qui ea blanditiis fugiat. Atque repellat earum eaque voluptates earum.'},
#  {'text': 'Officia totam reprehenderit nesciunt quae tempora. Totam veritatis magnam sequi aliquam. Quibusdam ratione maxime voluptatibus unde provident et voluptatem.'},
#  {'text': 'Accusamus culpa odit omnis voluptate et. Quam velit ut reiciendis aut necessitatibus repellendus. Vitae dolore cumque veritatis possimus ex consequuntur laborum.'},
#  {'text': 'Pariatur consectetur dolores qui harum. Itaque tempore non dolor. At totam ex voluptates reprehenderit tenetur vel. Cumque optio quidem consectetur quaerat optio.'},
#  {'text': 'Eveniet ipsum ipsam in libero numquam quis. Et unde voluptas explicabo harum quidem assumenda. Dicta porro velit voluptatum officia.'},
#  {'text': 'Quas maiores suscipit voluptatum ipsam magnam facere. Sint consequuntur aperiam est rerum atque. At pariatur veniam vitae ducimus ipsa perspiciatis quia ut.'},
#  {'text': 'Voluptatum cumque blanditiis non rerum animi. Nulla dolores architecto laboriosam quasi a recusandae quo. Voluptatem temporibus accusamus dolores.'},
#  {'text': 'Ipsa molestiae sapiente error commodi nisi. Ducimus ipsa nulla omnis et. Numquam maiores iusto maiores. Aut itaque dolorum omnis distinctio inventore.'},
#  {'text': 'Dolore libero illo vel doloremque repellendus amet. Dignissimos quaerat deleniti itaque veniam inventore. Et praesentium soluta tempore dolorum blanditiis. Ea earum facilis eligendi.'},
#  {'text': 'Laborum cupiditate rerum aliquam esse doloremque cum itaque. Dignissimos nesciunt et dolorem eligendi. Repellendus vel suscipit quia doloribus nam.'},
#  {'text': 'Repellat hic cupiditate suscipit repellat. Occaecati laboriosam nemo quis maxime tempore recusandae. Voluptatibus odio iste laborum impedit magnam soluta. Et maxime culpa sequi.'},
#  {'text': 'Dolorum facere quae eum eligendi mollitia quisquam iusto nostrum. Hic quas dolores iusto quia. Eveniet facere debitis dicta unde odit at magni.'},
#  {'text': 'Excepturi laboriosam temporibus a molestiae cumque eligendi quo. Saepe error id aut debitis quod laboriosam dolores incidunt. Ratione odio nobis qui cumque labore vitae voluptates totam.'},
#  {'text': 'Iure natus libero cupiditate ea sit repellendus quos. Praesentium iste temporibus voluptates nam. Repellat repellat distinctio voluptatibus sit explicabo.'},
#  {'text': 'Nostrum reiciendis voluptate quam inventore. Dolore officia aliquid laudantium repudiandae commodi magni.'},
#  {'text': 'Beatae itaque saepe nulla consequuntur doloribus. Assumenda distinctio suscipit corrupti maiores. Nisi doloribus a quod eaque. Voluptatem voluptate incidunt exercitationem dignissimos.'},
#  {'text': 'Mollitia atque error repudiandae assumenda incidunt saepe repellendus illo. Nam sit eaque aspernatur at perspiciatis officia. Voluptates magnam deserunt cupiditate. Hic harum ipsa ratione dicta.'},
#  {'text': 'Ex fugit et nostrum facilis. Itaque similique doloribus quas ad.'},
#  {'text': 'Facere placeat magni unde iusto necessitatibus ab nostrum. Eaque a rerum nesciunt nobis aperiam delectus. Natus quisquam dignissimos maiores ipsam facere distinctio ratione blanditiis.'},
#  {'text': 'Officia debitis veniam quaerat voluptas hic esse distinctio. Error impedit nisi error eligendi blanditiis soluta natus. Pariatur quae doloremque illum voluptatibus.'},
#  {'text': 'Sequi perspiciatis accusantium perspiciatis saepe odit blanditiis. Sunt nemo optio veritatis.'},
#  {'text': 'Sunt exercitationem libero eaque dolorum id saepe. Consectetur cum animi doloremque aperiam nulla labore porro. Nulla occaecati consectetur cupiditate.'},
#  {'text': 'Hic accusamus id veniam sunt quidem laudantium eum iste. Maiores neque dicta tempora iure dolorem eum suscipit. Repellat quas omnis animi tempora.'},
#  {'text': 'Dolore numquam ex doloremque quibusdam. Repellat voluptatibus temporibus ullam ab officiis nemo. Fugiat repellat delectus saepe laborum. Autem quis neque praesentium non a est.'},
#  {'text': 'Laudantium ut eos magnam totam voluptates. Explicabo a sed corporis facere ut rerum asperiores. Recusandae dolore illum maiores dolorem. Laborum veritatis laborum eius in dolore ex.'},
#  {'text': 'Rem aliquid hic impedit pariatur alias nisi. Facilis modi iste asperiores pariatur delectus.'},
#  {'text': 'Et cumque commodi ad assumenda quos harum sed. Repellat hic id quam quidem illum nihil iste id. Distinctio nesciunt optio dolor quis quo excepturi.'},
#  {'text': 'Velit sapiente vero mollitia illum et neque et. Sequi nisi fugit recusandae tenetur beatae ab aperiam. Eum fugit rem excepturi adipisci debitis. Sunt itaque optio ex.'},
#  {'text': 'Dicta blanditiis tempore libero tempora tenetur earum. Nostrum cupiditate ipsam perspiciatis sunt pariatur dignissimos. Commodi earum hic dolorum praesentium totam corporis accusantium esse.'},
#  {'text': 'Recusandae expedita maxime ullam non. Necessitatibus nesciunt voluptates eligendi. Nisi et autem fuga cumque error. Excepturi quod corporis pariatur cumque nulla perferendis.'},
#  {'text': 'Porro veritatis officiis laboriosam veritatis magnam. Quam dolorum explicabo nemo exercitationem atque. Officiis dignissimos iure laborum neque incidunt.'},
#  {'text': 'Pariatur ab qui doloremque fuga aspernatur error. Aut quis in iusto. Officia expedita nobis perspiciatis ipsum. Dolor necessitatibus accusantium officia.'},
#  {'text': 'Architecto natus velit fugit magni aperiam impedit deserunt praesentium. Hic atque quas provident nesciunt. Optio tempore quos quaerat. Molestiae quo facilis error eius occaecati debitis molestiae.'},
#  {'text': 'Quia quos esse hic voluptatum a. Eos blanditiis maiores ducimus accusantium cum vel. Unde corporis adipisci minima. Pariatur hic ea odio fugit.'},
#  {'text': 'Doloremque unde aperiam voluptatem eligendi ab. Labore illum illo ipsa ea veniam modi esse. Minus temporibus architecto dolorum tempore ea dolorum.'},
#  {'text': 'Laudantium suscipit explicabo porro repellendus illum occaecati asperiores. Ipsum laborum natus architecto eaque id tempora. Atque temporibus ab consectetur ducimus ipsam magni deleniti.'},
#  {'text': 'Possimus nisi inventore asperiores velit asperiores. Aliquid totam suscipit distinctio accusamus ipsum. Quos unde repellat harum aliquam doloribus recusandae.'},
#  {'text': 'Ratione consequatur nemo ducimus praesentium sequi hic. Ad ab quisquam accusamus. Voluptas laudantium officia expedita ducimus sequi praesentium. Facere occaecati quae a quae.'},
#  {'text': 'Est quae labore sint optio nulla quaerat. Sequi ea ea maxime necessitatibus ratione saepe aperiam.\nMaiores iure atque quam accusamus sunt est. Nam excepturi dolore deleniti nisi. Odit ea culpa id.'},
#  {'text': 'Minima hic magni debitis ratione rerum iure fuga ratione. Similique libero vel ipsam odio blanditiis laboriosam in. Assumenda iusto ad quisquam similique provident dolore. Totam a tempora iste a quo.'},
#  {'text': 'Non illum laudantium ipsam hic at qui. Animi voluptas enim natus. Reprehenderit officia magnam nulla maxime quo. Error eos tempora voluptates deserunt tenetur. Eaque ipsa itaque sequi nostrum.'},
#  {'text': 'Molestiae alias sapiente eos itaque blanditiis laboriosam. Sunt corrupti laudantium modi velit numquam blanditiis. Illum quibusdam nemo possimus molestias autem consequuntur.'},
#  {'text': 'Veniam est illo nulla. Quo est atque cum doloremque modi similique. Deleniti sequi soluta saepe fugit iusto illo. Animi dolor voluptates maxime voluptatibus nemo.'},
#  {'text': 'Explicabo esse repellat commodi veritatis suscipit illum. Magnam delectus tenetur reiciendis fuga quisquam. Saepe delectus sapiente modi modi occaecati. Maxime hic dolore sequi debitis occaecati quo.'},
#  {'text': 'Consequuntur quidem et officiis exercitationem consequatur. Vero vitae alias voluptates voluptate eum voluptatem. Omnis hic cum molestias beatae voluptas. Architecto sapiente adipisci rerum rem.'},
#  {'text': 'Aliquam totam exercitationem quas consequuntur minima dignissimos quia. Ullam eaque sunt libero. Dolorem ut hic quam ipsa dolor ad. Quidem quidem dolores impedit.'},
#  {'text': 'Aliquam odio repudiandae vero possimus officia. Magnam facilis quis recusandae praesentium ullam ullam doloribus. Hic voluptatem perspiciatis explicabo omnis voluptas suscipit nobis.'},
#  {'text': 'Nostrum itaque debitis beatae eum. Porro natus similique ratione optio quae.'},
#  {'text': 'Cumque quidem sint sit recusandae tempora. Minima eveniet sequi repudiandae tenetur esse error unde. Voluptatum rerum quod a iste.'},
#  {'text': 'Necessitatibus quaerat facere quis atque at magni. Perferendis odio magnam vel totam perspiciatis. Dolore assumenda consequuntur unde hic voluptas. Natus odit temporibus illum sunt aliquam ipsa.'},
#  {'text': 'In voluptates quod officia vero suscipit temporibus. Laudantium iure quae quisquam doloremque commodi. Fuga numquam aliquam minima.'},
#  {'text': 'Voluptatem eligendi sapiente cum iusto voluptatibus. Culpa recusandae cupiditate deserunt illum ullam possimus natus odit. Assumenda iure vero eveniet explicabo aspernatur quo sapiente voluptatibus.'},
#  {'text': 'Eius amet fugiat quam aut totam accusamus. Fugit impedit eaque asperiores deleniti debitis repellendus. Similique placeat dolore sed delectus nostrum.'},
#  {'text': 'Blanditiis cum facere explicabo est atque nam nam. Incidunt quod vitae cupiditate veritatis quisquam. Animi natus enim error quae.'},
#  {'text': 'Aliquid saepe et eveniet omnis. Vel reprehenderit magnam dolore officia.'},
#  {'text': 'Aspernatur dolor id dignissimos quis molestias repellat. Culpa corporis quasi magnam autem. Molestias exercitationem vero eos voluptatem fuga id.'},
#  {'text': 'Illo asperiores nisi ipsa asperiores. Aut dolorem provident reprehenderit asperiores expedita necessitatibus illo. Aut optio sapiente nostrum quos tenetur.'},
#  {'text': 'Qui laboriosam consequatur neque. Facere dolores non atque laborum perferendis. Cupiditate a praesentium tempora cupiditate beatae ad corporis. Facilis deserunt nihil unde consequuntur.'},
#  {'text': 'Quae rerum iure omnis commodi. Quo dolor fugit voluptatum dolorem tempore inventore. Corrupti officia delectus nisi iure cupiditate veritatis.'},
#  {'text': 'Debitis doloribus doloremque dolor praesentium assumenda. Similique illo corrupti enim temporibus ratione. Iste ad officiis veniam tempore repudiandae atque occaecati.'},
#  {'text': 'Impedit eius reprehenderit hic blanditiis. Alias veritatis consectetur dolorum in magni itaque. Libero necessitatibus aspernatur quae ipsum fugit.'},
#  {'text': 'Eaque minima porro ullam ut totam velit excepturi ex. Aut reprehenderit unde numquam in. Ex voluptas eveniet nostrum omnis voluptatibus debitis temporibus.'},
#  {'text': 'Vero veniam iure doloremque quia cumque nesciunt. Quam illo dolores neque animi voluptatibus sunt quod odio. Quod error accusamus quia mollitia commodi. Cum corporis sit error fugit at ratione.'},
#  {'text': 'Architecto iusto quisquam minus. Totam vitae adipisci qui necessitatibus deserunt. Iusto perspiciatis saepe blanditiis neque dicta molestiae nesciunt repellat.'},
#  {'text': 'Aliquid architecto omnis at nisi. Inventore consequatur nihil accusantium cupiditate nisi. Repellat vitae ex tenetur cum corrupti odit.'},
#  {'text': 'Tempore praesentium amet earum saepe nisi amet. Natus eveniet laboriosam nihil inventore adipisci. Maxime quisquam iste molestias repudiandae fugiat dolor natus.'},
#  {'text': 'Eius aut cumque illo ab. In totam occaecati deserunt placeat reiciendis. Laudantium blanditiis at repellendus dicta dignissimos. Fugiat est repellat fuga ratione explicabo laudantium rerum.'},
#  {'text': 'Impedit facilis molestias saepe harum magnam cumque magni. Autem exercitationem ducimus ad blanditiis.'},
#  {'text': 'Dolorem eius vel dolorum. Odio vel commodi architecto modi at omnis facere eaque. Quaerat adipisci dolorem tenetur illum.'},
#  {'text': 'Eaque culpa iste quia sit beatae quas. Rem harum veniam quis culpa exercitationem et. Accusantium saepe quo nulla minus ut veritatis ipsam aspernatur.'},
#  {'text': 'Vel praesentium laborum dolor cupiditate. At eos qui assumenda quasi eius. Aspernatur esse totam hic odit.'},
#  {'text': 'Sed corrupti voluptatibus sint at. Molestiae sint facilis sint natus. Doloribus quibusdam qui dolore. Qui eveniet commodi porro eos.'},
#  {'text': 'Consectetur cumque neque alias esse eligendi magni nulla. Fugiat similique natus fuga adipisci fugiat. Explicabo doloremque eum sequi saepe dicta.'},
#  {'text': 'Saepe ut unde non assumenda at. Nostrum quae dicta fugit commodi. Rerum facilis corrupti facere deserunt ducimus.'},
#  {'text': 'Qui voluptas earum nobis veritatis. Provident quam molestias omnis alias minima consectetur itaque. Dignissimos voluptas eaque debitis odit doloribus odio accusamus.'},
#  {'text': 'Hic eveniet delectus magnam corrupti similique pariatur. Sunt mollitia doloribus labore.'},
#  {'text': 'Natus esse illo incidunt autem magni. Totam nam excepturi quisquam dignissimos ea. Eveniet vero suscipit tempora fuga. Neque quisquam suscipit minus similique.'},
#  {'text': 'Explicabo consequatur dicta incidunt ullam explicabo. Iusto consequuntur illum nulla similique nihil eius. Nulla voluptatibus ex ad.'},
#  {'text': 'Inventore a maxime quia amet voluptate. Repellat at suscipit id totam. Sed expedita ut occaecati recusandae eum fuga quisquam. Recusandae explicabo dolorum reiciendis consequatur qui.'},
#  {'text': 'Quam voluptate totam animi maiores unde aliquid doloremque. Quibusdam sit a corrupti officiis unde.\nLaborum dicta dolorum excepturi fuga placeat. Tempore impedit quidem quaerat.'},
#  {'text': 'Minima reiciendis omnis cum sequi. Rem magni voluptatum odio fugiat nam perferendis inventore. Similique rerum id iste officia ut.'},
#  {'text': 'Optio exercitationem dolorem id atque atque. Accusantium iusto voluptas aut nisi a.'},
#  {'text': 'Cupiditate consequatur numquam sequi. Saepe consectetur corporis illo amet blanditiis qui ducimus. Dolores itaque a esse iste exercitationem iste. Quo expedita vero accusantium ab cum.'},
#  {'text': 'Officia aliquam veritatis vel eos error blanditiis consequatur repudiandae. Fugiat sint esse necessitatibus eveniet assumenda ad natus.'},
#  {'text': 'Nesciunt perspiciatis tempore aliquam eius. Dolorem placeat officiis ex. Magni quae nesciunt voluptas nihil.'},
#  {'text': 'Numquam nulla corporis ullam voluptate explicabo perferendis eligendi laboriosam. Ratione consequatur architecto quia ullam. Saepe nulla voluptatum cumque atque.'},
#  {'text': 'Error rerum incidunt beatae modi error sit cumque qui. Voluptatum facilis repellendus aut repellat numquam ab. Fuga ducimus tenetur velit amet dolorem amet aliquam.'},
#  {'text': 'Reprehenderit fugiat excepturi iste. Aperiam dolore odio asperiores ipsum explicabo molestiae pariatur. Sint natus quisquam numquam ea sit.'},
#  {'text': 'Impedit optio iure hic ex soluta. Perspiciatis architecto a officiis quaerat alias adipisci delectus mollitia. Distinctio adipisci velit dolorum tempore tempore recusandae.'},
#  {'text': 'Ducimus officiis voluptate dolorum. Deserunt ab corrupti deleniti facilis corrupti at.'},
#  {'text': 'Nulla optio recusandae pariatur fuga atque harum. Eveniet quidem nam id maxime quisquam quos. Laborum omnis assumenda ducimus corrupti dolore. Dolore sed cupiditate molestiae numquam.'},
#  {'text': 'Laudantium delectus molestiae eius aliquid. Accusantium sit molestiae dignissimos cum neque totam. Nobis libero adipisci veritatis exercitationem. Laborum fugit sapiente delectus ipsam corrupti nam.'},
#  {'text': 'Maxime corporis minus amet asperiores earum laboriosam non ullam. Vero rem sint sint vero minima ad esse. Eos adipisci ab velit porro illum deserunt explicabo.'},
#  {'text': 'Nihil explicabo voluptates ipsum eius esse alias. Cum aut eum exercitationem possimus eius. Impedit animi eius nostrum modi sapiente consectetur accusantium.'},
#  {'text': 'Asperiores dignissimos at nihil consequatur molestiae quos. Quia eum reiciendis expedita dolore. Quas accusantium enim laborum architecto at.'},
#  {'text': 'Esse occaecati consequatur nam iste ipsum dignissimos omnis facilis. Quod natus eaque ipsam totam. Ipsa reprehenderit nesciunt rerum at culpa animi quidem ab. Id facilis unde et repellat.'},
#  {'text': 'Ex distinctio eligendi minima magni voluptatum quasi. Deserunt dolorum nesciunt commodi perspiciatis soluta. Nisi recusandae amet nulla similique harum.'},
#  {'text': 'Repellat nemo magnam velit. Veritatis alias cupiditate cumque perferendis. Illo eaque laudantium adipisci cum praesentium deleniti eos. Nulla odio tempora iste nesciunt eaque.'},
#  {'text': 'Aut deleniti fuga eaque est repudiandae suscipit. Ratione atque unde enim omnis debitis vitae. Excepturi veritatis dolor fugit sed.'},
#  {'text': 'Quos aspernatur rerum sint possimus vero praesentium. Adipisci voluptate ab nostrum expedita recusandae. Ut et dignissimos et eius accusamus consequuntur omnis incidunt.'},
#  {'text': 'Quasi autem praesentium maxime quia maiores. Nisi adipisci ab repellendus earum nobis aliquam repellat. Modi aut incidunt eligendi nulla. Eligendi sunt quam expedita beatae vero.'},
#  {'text': 'Commodi vel veritatis odit. Hic distinctio quibusdam quae. Impedit atque quia labore voluptas quod magnam odit. Libero nobis cum neque quidem.'},
#  {'text': 'Molestias corrupti consectetur cupiditate aspernatur dolorem dolore. Ipsa assumenda nesciunt maxime minus. Laboriosam fuga quisquam tempore minima.'},
#  {'text': 'Dolor omnis ipsam a dolorum ducimus at natus. Vel fuga natus adipisci. Delectus fuga repudiandae placeat. Consectetur soluta exercitationem repellendus vitae animi.'},
#  {'text': 'In laborum aliquam maiores porro dolorem non magnam. Aliquid sapiente mollitia inventore. Sed impedit asperiores dignissimos aspernatur ipsa deserunt quo dolorum.'},
#  {'text': 'Occaecati architecto rem inventore consectetur. Consectetur culpa qui temporibus harum a. Magnam repellendus id laudantium dicta dolore. Dignissimos perferendis impedit dicta fugiat quis tempore.'},
#  {'text': 'Voluptates libero rerum placeat alias dicta. Asperiores unde necessitatibus soluta saepe nobis. Pariatur officiis itaque quaerat numquam sequi quisquam.'},
#  {'text': 'Temporibus architecto delectus maiores soluta. Inventore reprehenderit eaque corrupti ipsa voluptas. Nemo hic adipisci et aliquam. Accusantium a dolor assumenda esse excepturi sint.'},
#  {'text': 'Ad totam exercitationem pariatur tempore. Nisi nemo voluptatem fugiat. A illum cum nisi excepturi maiores harum. Iste iure provident adipisci soluta nostrum. Omnis at ad suscipit id illo quos quia.'},
#  {'text': 'Eveniet minima modi consectetur dolores totam id. Quaerat quibusdam tempora ad quisquam. Ad exercitationem earum excepturi nam rerum unde quas.'},
#  {'text': 'Illo nemo officiis autem deleniti accusamus eius. Nemo accusantium nihil laudantium. Doloribus hic atque rerum impedit facilis.'},
#  {'text': 'Quia veritatis doloribus nihil quae voluptas ipsum. Placeat enim voluptatibus quia culpa nisi ducimus. Ipsam tenetur possimus minus laborum amet amet nobis voluptate.'},
#  {'text': 'Qui qui a nihil odit enim. Voluptates maxime est error. Dignissimos esse quis ipsa ullam dignissimos saepe. Totam sequi omnis atque odio atque magni provident. In deserunt nemo maxime earum.'},
#  {'text': 'Aspernatur beatae facere aut illum cupiditate ex. Nobis assumenda nam quam corporis. Facere voluptatum nulla possimus optio quod.\nCommodi laudantium quam soluta. Dolorem reprehenderit eius cum enim.'},
#  {'text': 'Ab repellat incidunt suscipit possimus dolorem. Cumque id accusantium provident quo optio delectus sed. Quisquam laudantium similique nobis explicabo.'},
#  {'text': 'Quae incidunt eos excepturi. Consequatur ea totam voluptatibus autem incidunt libero facere. Quidem nisi laudantium facilis dicta porro. In eius quos voluptatem delectus rerum nulla dolor quam.'},
#  {'text': 'Natus blanditiis voluptate culpa vel. Ipsum quasi nulla eveniet facere.'},
#  {'text': 'Molestiae ducimus voluptate iste dolorum nam. A voluptate rerum natus tenetur. Voluptates illum iste voluptatibus enim. Consequatur optio iste dolor natus ipsam.'},
#  {'text': 'Impedit dolores numquam nihil. Nostrum veritatis iusto facilis quas. Provident corrupti placeat atque quas.'}]

# %% [markdown]
# #### Задача 1.3 (1 балл)

# %% [markdown]
# Сделайте запрос к коллекции `movies` и выведите количество документов, в которых в качестве первого жанра фильма (поле `genres`) указано значение Horror.
#
# **Для справки:**
#
# 1. Обратите внимание, что поле `genres` представляет собой массив (индексация массивов начинается с нуля).
# 1. При работе в MongoDB Shell для подсчета количества документов в курсоре можно использовать метод `count()`, однако он был удален в последних версиях библиотеки PyMongo. В случае затруднений с использованием функций Mongo можно использовать для подсчета документов средства Python.

# %%
# Ваш код здесь
print(
    db.movies.count_documents({'genres.0' : 'Horror'})
    )
# Out:
# 700

# %% [markdown]
# #### Задача 1.4 (2 балла)

# %% [markdown]
# Выведите из коллекции `movies` документы о фильмах, которые в качестве первого жанра определены как Film-Noir либо Horror и были выпущены в период с 1940 по 1949 г. (включительно).

# %%
# Ваш код здесь
list(
    db.movies.find({'$and' : [{'genres.0': {'$in': ['Film-Noir', 'Horror']}}, {'year':{'$gte': 1940, '$lte': 1949}}]})
    )
# Out:
# [{'_id': ObjectId('573a1393f29313caabcdc814'),
#   'plot': "An American man marries a Serbian immigrant who fears that she will turn into the cat person of her homeland's fables if they are intimate together.",
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 73,
#   'rated': 'APPROVED',
#   'cast': ['Simone Simon', 'Kent Smith', 'Tom Conway', 'Jane Randolph'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNzI4YWY0NWQtNWI5YS00MGE4LWE4YTgtMzBmOWIwMzdiYTRiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Cat People',
#   'fullplot': 'Irena Dubrovna, a beautiful and mysterious Serbian-born fashion artist living in New York City, falls in love with and marries average-Joe American Oliver Reed. Their marriage suffers though, as Irena believes that she suffers from an ancient curse- whenever emotionally aroused, she will turn into a panther and kill. Oliver thinks that is absurd and childish, so he sends her to psychiatrist Dr. Judd to cure her. Easier said than done...',
#   'languages': ['English', 'Czech', 'Serbian'],
#   'released': datetime.datetime(1942, 12, 25, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['DeWitt Bodeen'],
#   'awards': {'wins': 1, 'nominations': 2, 'text': '1 win & 2 nominations.'},
#   'lastupdated': '2015-08-21 00:53:54.453000000',
#   'year': 1942,
#   'imdb': {'rating': 7.4, 'votes': 11589, 'id': 34587},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 7115},
#    'critic': {'rating': 8.3, 'numReviews': 40, 'meter': 93},
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 3, 25),
#    'consensus': 'Influential noir director Jacques Tourneau infused this sexy, moody horror film with some sly commentary about the psychology and the taboos of desire.',
#    'rotten': 3,
#    'production': 'RKO Pictures',
#    'fresh': 37},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdcd9d'),
#   'plot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis ...',
#   'genres': ['Horror'],
#   'runtime': 69,
#   'rated': 'APPROVED',
#   'cast': ['James Ellison', 'Frances Dee', 'Tom Conway', 'Edith Barrett'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZjQzMzliN2YtYTVhNC00Zjc4LThjMmYtMTE0ZGUzMWNmYzJlXkEyXkFqcGdeQXVyMTYxNjkxOQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'I Walked with a Zombie',
#   'fullplot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis as a result of fever. When she falls in love with Paul, Betsy determines to cure Jessica even if she needs to use a voodoo ceremony, to give Paul what she thinks he wants.',
#   'languages': ['English'],
#   'released': datetime.datetime(1943, 4, 30, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['Curt Siodmak (screenplay)',
#    'Ardel Wray (screenplay)',
#    'Inez Wallace (original story)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-16 00:16:16.823000000',
#   'year': 1943,
#   'imdb': {'rating': 7.3, 'votes': 6893, 'id': 36027},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 4884, 'meter': 75},
#    'dvd': datetime.datetime(2005, 10, 4, 0, 0),
#    'critic': {'rating': 8.1, 'numReviews': 26, 'meter': 92},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 16, 16),
#    'consensus': "Evocative direction by Jacques Tourneur collides with the low-rent production values of exploitateer Val Lewton in I Walked with a Zombie, a sultry sleeper that's simultaneously smarmy, eloquent and fascinating.",
#    'rotten': 2,
#    'production': 'Warner Home Video',
#    'fresh': 24}},
#  {'_id': ObjectId('573a1393f29313caabcdcdf5'),
#   'plot': 'A seemingly tame leopard used for a publicity stunt escapes and kills a young girl, spreading panic throughout a sleepy new Mexico town.',
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 66,
#   'rated': 'APPROVED',
#   'cast': ["Dennis O'Keefe", 'Margo', 'Jean Brooks', 'Isabel Jewell'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYmU4ZDI5NGMtYzM1OC00YTQ3LWI1NTEtNGM0Mzc0ZDA5NzI4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Leopard Man',
#   'fullplot': 'At the encouragement of her manager, a nightclub performer in New Mexico (Kiki Walker) takes a leashed leopard into the club as a publicity gimmick. But her rival, angered by the attempt to upstage, scares the animal and it bolts. In the days that follow, people are mauled and the countryside is combed for the loose creature. But Kiki and her manager begin to wonder if maybe the leopard is not responsible for the killings.',
#   'languages': ['English', 'Spanish'],
#   'released': datetime.datetime(1943, 5, 8, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['Ardel Wray (screenplay)',
#    'Edward Dein (additional dialogue)',
#    'Cornell Woolrich (novel)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-05 00:17:53.897000000',
#   'year': 1943,
#   'imdb': {'rating': 6.9, 'votes': 2889, 'id': 36104},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 1375, 'meter': 67},
#    'fresh': 15,
#    'critic': {'rating': 7.4, 'numReviews': 17, 'meter': 88},
#    'rotten': 2,
#    'lastUpdated': datetime.datetime(2015, 8, 27, 18, 6, 2)}},
#  {'_id': ObjectId('573a1393f29313caabcdd38c'),
#   'plot': 'A ruthless doctor and his young prize student find themselves continually harassed by their murderous supplier of illegal cadavers.',
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 77,
#   'rated': 'APPROVED',
#   'title': 'The Body Snatcher',
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNzNmOTE0YTktZGZmYS00N2RhLWI5NTgtYTAyZjZhYWExMmRmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': "In Edinburgh in 1831, Dr. Wolfe MacFarlane runs a medical school where Donald Fettes is a student. Fettes is interested in helping a young girl who has lost the use of her legs. He is certain that MacFarlane's surgical skills could be put to great use but he is reluctant to do so. The good Dr. MacFarlane has a secret that soon becomes all too obvious to young Fettes, who has only recently been promoted as his assistant: he has been paying a local cabbie, John Gray, to supply him with dead bodies for anatomical research. Gray constantly harasses MacFarlane and clearly has a hold over him dating to a famous trial many years before where Gray refused to identify the man for whom he was robbing graves. Fettes isn't aware of any of this but soon realizes exactly how Gray obtains the bodies they use in their anatomy classes.",
#   'languages': ['English'],
#   'cast': ['Boris Karloff', 'Bela Lugosi', 'Henry Daniell', 'Edith Atwater'],
#   'directors': ['Robert Wise'],
#   'writers': ['Robert Louis Stevenson (short story)',
#    'Philip MacDonald (written for the screen by)',
#    'Val Lewton (written for the screen by)'],
#   'awards': {'wins': 0, 'nominations': 3, 'text': '3 nominations.'},
#   'lastupdated': '2015-08-16 01:24:24.840000000',
#   'year': 1945,
#   'imdb': {'rating': 7.4, 'votes': 5509, 'id': 37549},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 3664, 'meter': 75},
#    'critic': {'rating': 6.8, 'numReviews': 16, 'meter': 81},
#    'lastUpdated': datetime.datetime(2015, 8, 21, 19, 11, 47),
#    'rotten': 3,
#    'production': 'RKO Pictures',
#    'fresh': 13}},
#  {'_id': ObjectId('573a1393f29313caabcdd3ed'),
#   'plot': 'An architect senses impending doom as his half-remembered recurring dream turns into reality. The guests at the country house encourage him to stay as they take turns telling supernatural tales.',
#   'genres': ['Horror'],
#   'runtime': 77,
#   'rated': 'APPROVED',
#   'cast': ['Mervyn Johns', 'Roland Culver', 'Mary Merrall', 'Googie Withers'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYTY2OTJjZjgtMzExMy00MWJlLTg2N2ItM2NhMDQxNTNkNjFhXkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Dead of Night',
#   'fullplot': "Architect Walter Craig, seeking the possibility of some work at a country farmhouse, soon finds himself once again stuck in his recurring nightmare. Dreading the end of the dream that he knows is coming, he must first listen to all the assembled guests' own bizarre tales.",
#   'languages': ['English', 'French'],
#   'released': datetime.datetime(1945, 10, 15, 0, 0),
#   'directors': ['Alberto Cavalcanti',
#    'Charles Crichton',
#    'Basil Dearden',
#    'Robert Hamer'],
#   'writers': ['H.G. Wells (original story)',
#    'E.F. Benson (original story)',
#    'John Baines (original story)',
#    'Angus MacPhail (original story)',
#    'John Baines (screenplay)',
#    'Angus MacPhail (screenplay)',
#    'T.E.B. Clarke (additional dialogue)'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-09-15 04:38:12.500000000',
#   'year': 1945,
#   'imdb': {'rating': 7.7, 'votes': 7116, 'id': 37635},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 3194, 'meter': 88},
#    'dvd': datetime.datetime(2009, 1, 27, 0, 0),
#    'critic': {'rating': 8.0, 'numReviews': 27, 'meter': 96},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 40, 43),
#    'consensus': 'With four accomplished directors contributing, Dead of Night is a classic horror anthology that remains highly influential.',
#    'rotten': 1,
#    'production': 'Universal Pictures',
#    'fresh': 26}},
#  {'_id': ObjectId('573a1393f29313caabcdd6e7'),
#   'plot': "Chuck Scott gets a job as chauffeur to tough guy Eddie Roman; but Chuck's involvement with Eddie's fearful wife becomes a nightmare.",
#   'genres': ['Film-Noir'],
#   'runtime': 86,
#   'rated': 'APPROVED',
#   'cast': ['Robert Cummings',
#    'Michèle Morgan',
#    'Steve Cochran',
#    'Lloyd Corrigan'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDI3OTM4NzMtNzQxMC00M2YxLWFmOTctNmUyNDBmMzIwZGI0XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Chase',
#   'fullplot': "Returning a lost wallet gains unemployed veteran Chuck Scott a job as chauffeur to Eddie Roman, a seeming gangster whose enemies have a way of meeting violent ends. The job proves nerve-wracking, and soon Chuck finds himself pledged to help Eddie's lovely, fearful, prisoner-wife Lorna to escape. The result leaves Chuck caught like a rat in a trap, vainly seeking a way out through dark streets. But the real chase begins when the strange plot virtually starts all over again...",
#   'languages': ['English', 'Spanish'],
#   'released': datetime.datetime(1946, 11, 16, 0, 0),
#   'directors': ['Arthur Ripley'],
#   'writers': ['Philip Yordan (written for the screen by)',
#    'Cornell Woolrich (book)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-01 00:47:13.267000000',
#   'year': 1946,
#   'imdb': {'rating': 6.7, 'votes': 766, 'id': 38409},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 92, 'meter': 40},
#    'dvd': datetime.datetime(2003, 8, 5, 0, 0),
#    'production': 'VCI',
#    'lastUpdated': datetime.datetime(2015, 8, 20, 18, 14, 48)}},
#  {'_id': ObjectId('573a1393f29313caabcde460'),
#   'plot': "Over-the-hill boxer Bill 'Stoker' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money ...",
#   'genres': ['Film-Noir', 'Sport'],
#   'runtime': 73,
#   'rated': 'APPROVED',
#   'cast': ['Robert Ryan', 'Audrey Totter', 'George Tobias', 'Alan Baxter'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjEwNjU3NzE1Nl5BMl5BanBnXkFtZTgwMjQ0MDgyMTE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Set-Up',
#   'fullplot': 'Over-the-hill boxer Bill \'Stoker\' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money for a "dive" from tough gambler Little Boy...without bothering to tell Stoker. Tension builds as Stoker hopes to "take" Tiger Nelson, unaware of what will happen to him if he does.',
#   'languages': ['English'],
#   'released': datetime.datetime(1949, 4, 2, 0, 0),
#   'directors': ['Robert Wise'],
#   'writers': ['Art Cohn (screenplay)',
#    'Joseph Moncure March (from the poem by)'],
#   'awards': {'wins': 3,
#    'nominations': 1,
#    'text': 'Nominated for 1 BAFTA Film Award. Another 2 wins & 1 nomination.'},
#   'lastupdated': '2015-08-26 00:13:18.837000000',
#   'year': 1949,
#   'imdb': {'rating': 7.8, 'votes': 5309, 'id': 41859},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 1692, 'meter': 88},
#    'dvd': datetime.datetime(2004, 7, 6, 0, 0),
#    'critic': {'rating': 5.9, 'numReviews': 7, 'meter': 86},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 33, 52),
#    'rotten': 1,
#    'fresh': 6}}]

# %% [markdown]
# #### Задача 1.5 (1 балл)

# %% [markdown]
# Модифицируйте запрос из задачи 1.4 таким образом, чтобы осуществить **проекцию**: результатом выборки должен стать список словарей, каждый из которых содержит только два поля: `title` и `year`.
#
# Для справки о проекции смотрите документацию по методу `find()` в PyMongo:
# https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html#pymongo.collection.Collection.find

# %%
# Ваш код здесь
list(
    db.movies.find({'$and' : [{'genres.0': {'$in': ['Film-Noir', 'Horror']}}, {'year':{'$gte': 1940, '$lte': 1949}}]}, {'_id':0, 'title':1, 'year':1})
    )
# Out:
# [{'title': 'Cat People', 'year': 1942},
#  {'title': 'I Walked with a Zombie', 'year': 1943},
#  {'title': 'The Leopard Man', 'year': 1943},
#  {'title': 'The Body Snatcher', 'year': 1945},
#  {'title': 'Dead of Night', 'year': 1945},
#  {'title': 'The Chase', 'year': 1946},
#  {'title': 'The Set-Up', 'year': 1949}]

# %% [markdown]
# ### Упражнение 2. Агрегация с помощью конвейеров

# %% [markdown]
# #### Задача 2.1 (3 балла)

# %% [markdown]
# В этой задаче вам требуется определить, какие фильмы получили наибольшее количество комментариев. Составьте для этого конвейер агрегации с перечисленными ниже этапами. Для удобства рекомендуется воспользоваться приложением Compass.
#
# **Этапы выполнения задания:**
#
# 1. Сгруппировать документы коллекции `comments` по полю `movie_id` и подсчитать количество комментариев для каждого фильма, записав его в поле `count`.
# 1. Отсортировать получившийся набор данных по убыванию количества комментариев (так, чтобы первый документ в этом наборе указывал на фильм с наибольшим количеством комментариев).
# 1. Используя оператор `$lookup`, присоединить коллекцию `movies` (по полю `movie_id`).
# 1. Выполнить проекцию, оставив в наборе данных только три поля: название фильма (`title`), год выпуска (`year`) и количество комментариев (поле `count`, добавленное на первом этапе). Для этого воспользуйтесь оператором `$project`: https://www.mongodb.com/docs/manual/reference/operator/aggregation/project/. Обратите внимание, что данные из коллекции `movies` (`title` и `year`) на этом этапе окажутся внутри массива.
# 1. Применить оператор `$unwind`, чтобы деконструировать этот массив (подробнее на https://www.mongodb.com/docs/manual/reference/operator/aggregation/unwind/). В результате массив должен превратиться в одиночный объект.
# 1. Применить оператор `$addFields`, чтобы добавить поля `title` и `year` на верхний уровень структуры документа (https://www.mongodb.com/docs/manual/reference/operator/aggregation/addFields/).
# 1. Выполнить проекцию еще раз, чтобы удалить поле с массивом.
#
# Ваш алгоритм решения может отличаться от приведенного здесь. Главное — достичь цели: **получить плоский набор данных с тремя полями** (`count` — количество комментариев, `year` — год выпуска, `title` — название фильма).
#
# Скопируйте полученный конвейер в этот документ в виде кода на Python и выведите его на экран в виде списка словарей.

# %%
# Ваш код здесь

result = client['sample_mflix']['comments'].aggregate([
    {
        '$group': {
            '_id': '$movie_id', 
            'count': {
                '$count': {}
            }
        }
    }, {
        '$sort': {
            'count': -1
        }
    }, {
        '$lookup': {
            'from': 'movies', 
            'localField': '_id', 
            'foreignField': '_id', 
            'as': 'movie'
        }
    }, {
        '$project': {
            '_id': 0, 
            'movie.title': 1, 
            'movie.year': 1, 
            'count': 1
        }
    }, {
        '$unwind': {
            'path': '$movie', 
            'includeArrayIndex': 'string', 
            'preserveNullAndEmptyArrays': False
        }
    }, {
        '$addFields': {
            'year': '$movie.year', 
            'title': '$movie.title'
        }
    }, {
        '$project': {
            'count': 1, 
            'title': 1, 
            'year': 1
        }
    }
])

data = list(result)
data
# Out:
# [{'count': 161, 'year': 2009, 'title': 'The Taking of Pelham 1 2 3'},
#  {'count': 158, 'year': 2001, 'title': "Ocean's Eleven"},
#  {'count': 158, 'year': 2004, 'title': '50 First Dates'},
#  {'count': 158, 'year': 2002, 'title': 'About a Boy'},
#  {'count': 158, 'year': 2009, 'title': 'Terminator Salvation'},
#  {'count': 157, 'year': 2009, 'title': 'Sherlock Holmes'},
#  {'count': 157, 'year': 1999, 'title': 'The Mummy'},
#  {'count': 155, 'year': 2008, 'title': 'Hellboy II: The Golden Army'},
#  {'count': 154, 'year': 2001, 'title': 'The Mummy Returns'},
#  {'count': 154,
#   'year': 2004,
#   'title': 'Anchorman: The Legend of Ron Burgundy'},
#  {'count': 153, 'year': 1982, 'title': 'E.T. the Extra-Terrestrial'},
#  {'count': 153, 'year': 2008, 'title': 'Wanted'},
#  {'count': 153, 'year': 1996, 'title': 'Mission: Impossible'},
#  {'count': 153, 'year': 2000, 'title': 'X-Men'},
#  {'count': 153, 'year': 1999, 'title': 'American Pie'},
#  {'count': 153, 'year': 1950, 'title': 'Cinderella'},
#  {'count': 153,
#   'year': 2007,
#   'title': "Pirates of the Caribbean: At World's End"},
#  {'count': 153, 'year': 2003, 'title': 'Bruce Almighty'},
#  {'count': 152, 'year': 2002, 'title': 'The Ring'},
#  {'count': 152, 'year': 2000, 'title': 'Gladiator'},
#  {'count': 151, 'year': 2004, 'title': 'Meet the Fockers'},
#  {'count': 151, 'year': 1994, 'title': 'The Mask'},
#  {'count': 151, 'year': 2003, 'title': 'The Matrix Reloaded'},
#  {'count': 150, 'year': 1999, 'title': 'Big Daddy'},
#  {'count': 150, 'year': 1999, 'title': 'Toy Story 2'},
#  {'count': 148, 'year': 1993, 'title': 'Jurassic Park'},
#  {'count': 148, 'year': 1995, 'title': 'Braveheart'},
#  {'count': 148, 'year': 2007, 'title': 'I Am Legend'},
#  {'count': 147, 'year': 2008, 'title': 'The Express'},
#  {'count': 147, 'year': 1975, 'title': 'Jaws'},
#  {'count': 147, 'year': 2000, 'title': 'Scary Movie'},
#  {'count': 146, 'year': 2007, 'title': 'I Now Pronounce You Chuck & Larry'},
#  {'count': 146, 'year': 1996, 'title': 'Twister'},
#  {'count': 145, 'year': 1994, 'title': 'Dumb & Dumber'},
#  {'count': 145, 'year': 2000, 'title': 'Cast Away'},
#  {'count': 145, 'year': 2006, 'title': '300'},
#  {'count': 144, 'year': 2007, 'title': 'Hostel: Part II'},
#  {'count': 144, 'year': 2001, 'title': 'Zoolander'},
#  {'count': 144, 'year': 2009, 'title': 'The Last House on the Left'},
#  {'count': 144, 'year': 2009, 'title': 'I Love You, Man'},
#  {'count': 144, 'year': 1998, 'title': 'Saving Private Ryan'},
#  {'count': 144, 'year': 1982, 'title': 'Dègkeselyè'},
#  {'count': 144, 'year': 2007, 'title': 'The Simpsons Movie'},
#  {'count': 144, 'year': 2005, 'title': 'King Kong'},
#  {'count': 144, 'year': 2003, 'title': 'School of Rock'},
#  {'count': 144, 'year': 2007, 'title': 'Spider-Man 3'},
#  {'count': 144, 'year': 2009, 'title': 'The Hangover'},
#  {'count': 144, 'year': 1999, 'title': 'The Green Mile'},
#  {'count': 144, 'year': 1992, 'title': 'Aladdin'},
#  {'count': 143, 'year': 2002, 'title': 'Ice Age'},
#  {'count': 143, 'year': 2003, 'title': 'Kill Bill: Vol. 1'},
#  {'count': 143, 'year': 2001, 'title': 'Rush Hour 2'},
#  {'count': 143, 'year': 1993, 'title': 'The Jungle Creature: Hugo'},
#  {'count': 143, 'year': 2002, 'title': '8 Mile'},
#  {'count': 143,
#   'year': 2002,
#   'title': 'Harry Potter and the Chamber of Secrets'},
#  {'count': 143, 'year': 2009, 'title': 'Up'},
#  {'count': 142, 'year': 2009, 'title': 'Star Trek'},
#  {'count': 142, 'year': 1989, 'title': 'Back to the Future Part II'},
#  {'count': 142, 'year': 1994, 'title': 'Speed'},
#  {'count': 142, 'year': 2010, 'title': 'Shutter Island'},
#  {'count': 142, 'year': 2004, 'title': "Ocean's Twelve"},
#  {'count': 141, 'year': 1995, 'title': 'Billy Madison'},
#  {'count': 141, 'year': 2007, 'title': 'Live Free or Die Hard'},
#  {'count': 141, 'year': 2007, 'title': '1408'},
#  {'count': 141, 'year': 2007, 'title': 'Evan Almighty'},
#  {'count': 141, 'year': 1998, 'title': 'Rush Hour'},
#  {'count': 141, 'year': 2001, 'title': 'The Princess Diaries'},
#  {'count': 141, 'year': 2003, 'title': 'Freaky Friday'},
#  {'count': 140, 'year': 2005, 'title': 'War of the Worlds'},
#  {'count': 140, 'year': 2002, 'title': 'Men in Black II'},
#  {'count': 140, 'year': 1990, 'title': 'Back to the Future Part III'},
#  {'count': 140, 'year': 2007, 'title': 'The Bourne Ultimatum'},
#  {'count': 140, 'year': 2007, 'title': 'Ghost Rider'},
#  {'count': 140, 'year': 2005, 'title': 'Mr. & Mrs. Smith'},
#  {'count': 140, 'year': 2003, 'title': 'X-Men 2'},
#  {'count': 140, 'year': 2003, 'title': 'Cheaper by the Dozen'},
#  {'count': 139, 'year': 1997, 'title': 'Liar Liar'},
#  {'count': 139, 'year': 2003, 'title': 'The Matrix Revolutions'},
#  {'count': 139, 'year': 1995, 'title': 'Ace Ventura: When Nature Calls'},
#  {'count': 139, 'year': 2005, 'title': 'V for Vendetta'},
#  {'count': 139, 'year': 2009, 'title': 'Saw VI'},
#  {'count': 139, 'year': 1996, 'title': 'Happy Gilmore'},
#  {'count': 139, 'year': 1939, 'title': 'The Wizard of Oz'},
#  {'count': 138, 'year': 2009, 'title': 'A Christmas Carol'},
#  {'count': 138, 'year': 2000, 'title': 'Gone in Sixty Seconds'},
#  {'count': 138, 'year': 2003, 'title': 'How to Lose a Guy in 10 Days'},
#  {'count': 138, 'year': 2001, 'title': 'Donnie Darko'},
#  {'count': 138, 'year': 2004, 'title': 'Shark Tale'},
#  {'count': 138,
#   'year': 2001,
#   'title': "Harry Potter and the Sorcerer's Stone"},
#  {'count': 138, 'year': 1999, 'title': 'The Matrix'},
#  {'count': 138, 'year': 2000, 'title': 'How the Grinch Stole Christmas'},
#  {'count': 138, 'year': 2012, 'title': 'Men in Black 3'},
#  {'count': 138,
#   'year': 2007,
#   'title': 'Sweeney Todd: The Demon Barber of Fleet Street'},
#  {'count': 137, 'year': 2002, 'title': 'My Big Fat Greek Wedding'},
#  {'count': 137,
#   'year': 2005,
#   'title': 'Star Wars: Episode III - Revenge of the Sith'},
#  {'count': 137, 'year': 1999, 'title': 'Fight Club'},
#  {'count': 137, 'year': 2003, 'title': 'Elf'},
#  {'count': 137, 'year': 1996, 'title': 'Independence Day'},
#  {'count': 137, 'year': 2005, 'title': 'The 40-Year-Old Virgin'},
#  {'count': 136, 'year': 2008, 'title': 'The Dark Knight'},
#  {'count': 136, 'year': 1988, 'title': 'Beetlejuice'},
#  {'count': 136, 'year': 1998, 'title': 'The Waterboy'},
#  {'count': 136, 'year': 1994, 'title': 'Forrest Gump'},
#  {'count': 136, 'year': 1993, 'title': 'The Nightmare Before Christmas'},
#  {'count': 136, 'year': 2000, 'title': 'Cast Away'},
#  {'count': 136, 'year': 2002, 'title': 'The Bourne Identity'},
#  {'count': 136, 'year': 1976, 'title': 'Rocky'},
#  {'count': 136,
#   'year': 2004,
#   'title': 'Harry Potter and the Prisoner of Azkaban'},
#  {'count': 135, 'year': 1989, 'title': 'Indiana Jones and the Last Crusade'},
#  {'count': 135, 'year': 1989, 'title': 'Honey, I Shrunk the Kids'},
#  {'count': 135,
#   'year': 2005,
#   'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe'},
#  {'count': 135, 'year': 2000, 'title': 'Bring It On'},
#  {'count': 135, 'year': 2002, 'title': 'Signs'},
#  {'count': 135, 'year': 2009, 'title': 'Push'},
#  {'count': 134, 'year': 2005, 'title': 'Sin City'},
#  {'count': 134, 'year': 2005, 'title': 'Fantastic Four'},
#  {'count': 134, 'year': 1999, 'title': 'The Mummy'},
#  {'count': 134, 'year': 2004, 'title': 'Spider-Man 2'},
#  {'count': 134,
#   'year': 2007,
#   'title': 'Fantastic 4: Rise of the Silver Surfer'},
#  {'count': 134, 'year': 2001, 'title': 'American Pie 2'},
#  {'count': 134, 'year': 1967, 'title': 'The Jungle Book'},
#  {'count': 134, 'year': 2001, 'title': 'Monsters, Inc.'},
#  {'count': 134, 'year': 2009, 'title': 'Transformers: Revenge of the Fallen'},
#  {'count': 134, 'year': 2000, 'title': 'Miss Congeniality'},
#  {'count': 134, 'year': 1991, 'title': 'Beauty and the Beast'},
#  {'count': 134, 'year': 2009, 'title': 'The Uninvited'},
#  {'count': 133, 'year': 2004, 'title': 'Shrek 2'},
#  {'count': 133, 'year': 2007, 'title': 'Blades of Glory'},
#  {'count': 133, 'year': 2009, 'title': 'The Ugly Truth'},
#  {'count': 133,
#   'year': 2003,
#   'title': 'The Lord of the Rings: The Return of the King'},
#  {'count': 133, 'year': 2001, 'title': 'The Fast and the Furious'},
#  {'count': 132, 'year': 1993, 'title': 'Free Willy'},
#  {'count': 132, 'year': 2007, 'title': 'Shrek the Third'},
#  {'count': 132, 'year': 1994, 'title': 'Ace Ventura: Pet Detective'},
#  {'count': 132, 'year': 2009, 'title': "The Time Traveler's Wife"},
#  {'count': 132, 'year': 2002, 'title': 'Catch Me If You Can'},
#  {'count': 132, 'year': 1994, 'title': 'The Lion King'},
#  {'count': 132, 'year': 2003, 'title': '2 Fast 2 Furious'},
#  {'count': 132, 'year': 1997, 'title': 'Men in Black'},
#  {'count': 131, 'year': 1994, 'title': 'The Shawshank Redemption'},
#  {'count': 131, 'year': 1995, 'title': 'Toy Story'},
#  {'count': 131, 'year': 2004, 'title': 'Shark Tale'},
#  {'count': 131, 'year': 2009, 'title': 'Drag Me to Hell'},
#  {'count': 131, 'year': 1972, 'title': 'The Godfather'},
#  {'count': 131, 'year': 1999, 'title': 'American Beauty'},
#  {'count': 131, 'year': 2000, 'title': 'Meet the Parents'},
#  {'count': 131, 'year': 1999, 'title': 'The Sixth Sense'},
#  {'count': 131, 'year': 1998, 'title': 'Doctor Dolittle'},
#  {'count': 131, 'year': 2001, 'title': 'Shrek'},
#  {'count': 131, 'year': 1977, 'title': 'Star Wars: Episode IV - A New Hope'},
#  {'count': 131, 'year': 2009, 'title': 'The Unborn'},
#  {'count': 130, 'year': 2009, 'title': 'G.I. Joe: The Rise of Cobra'},
#  {'count': 130, 'year': 2004, 'title': 'The Day After Tomorrow'},
#  {'count': 130, 'year': 1990, 'title': 'Home Alone'},
#  {'count': 130, 'year': 1991, 'title': 'Hook'},
#  {'count': 130, 'year': 2006, 'title': 'Ice Age: The Meltdown'},
#  {'count': 130, 'year': 1990, 'title': 'Pretty Woman'},
#  {'count': 129, 'year': 1995, 'title': 'Bad Boys'},
#  {'count': 129, 'year': 2012, 'title': 'The Dark Knight Rises'},
#  {'count': 129, 'year': 2009, 'title': 'Avatar'},
#  {'count': 128, 'year': 2002, 'title': 'Mr. Deeds'},
#  {'count': 128, 'year': 1997, 'title': 'Titanic'},
#  {'count': 128, 'year': 2006, 'title': 'Night at the Museum'},
#  {'count': 128, 'year': 2008, 'title': 'Stop-Loss'},
#  {'count': 128, 'year': 1989, 'title': 'The Little Mermaid'},
#  {'count': 128, 'year': 1997, 'title': 'Liar Liar'},
#  {'count': 128, 'year': 1964, 'title': 'Mary Poppins'},
#  {'count': 128, 'year': 1992, 'title': 'Sister Act'},
#  {'count': 128, 'year': 2000, 'title': 'X-Men'},
#  {'count': 128, 'year': 2002, 'title': 'A Walk to Remember'},
#  {'count': 128, 'year': 2004, 'title': 'Troy'},
#  {'count': 128, 'year': 2008, 'title': 'The Curious Case of Benjamin Button'},
#  {'count': 128,
#   'year': 1997,
#   'title': 'Austin Powers: International Man of Mystery'},
#  {'count': 128, 'year': 2004, 'title': 'A Cinderella Story'},
#  {'count': 127,
#   'year': 2003,
#   'title': 'Pirates of the Caribbean: The Curse of the Black Pearl'},
#  {'count': 127, 'year': 2008, 'title': 'The Incredible Hulk'},
#  {'count': 127, 'year': 2009, 'title': 'Funny People'},
#  {'count': 127, 'year': 2008, 'title': 'Taken'},
#  {'count': 127, 'year': 1998, 'title': 'The Wedding Singer'},
#  {'count': 127, 'year': 2008, 'title': 'Slumdog Millionaire'},
#  {'count': 127, 'year': 2009, 'title': 'Inglourious Basterds'},
#  {'count': 127,
#   'year': 2002,
#   'title': 'The Lord of the Rings: The Two Towers'},
#  {'count': 126, 'year': 2003, 'title': 'Anger Management'},
#  {'count': 126, 'year': 1981, 'title': 'Raiders of the Lost Ark'},
#  {'count': 126, 'year': 2002, 'title': 'Austin Powers in Goldmember'},
#  {'count': 126, 'year': 1993, 'title': 'Mrs. Doubtfire'},
#  {'count': 126, 'year': 1955, 'title': 'Lady and the Tramp'},
#  {'count': 125, 'year': 1991, 'title': 'Terminator 2: Judgment Day'},
#  {'count': 125, 'year': 2001, 'title': 'Pearl Harbor'},
#  {'count': 125, 'year': 1989, 'title': 'Batman'},
#  {'count': 124,
#   'year': 1999,
#   'title': 'Austin Powers: The Spy Who Shagged Me'},
#  {'count': 124, 'year': 1998, 'title': 'Armageddon'},
#  {'count': 123, 'year': 2000, 'title': 'Scary Movie'},
#  {'count': 123, 'year': 2006, 'title': 'Cars'},
#  {'count': 123,
#   'year': 2009,
#   'title': 'Harry Potter and the Half-Blood Prince'},
#  {'count': 123, 'year': 2007, 'title': 'National Treasure: Book of Secrets'},
#  {'count': 122, 'year': 2009, 'title': 'The Proposal'},
#  {'count': 122, 'year': 2007, 'title': "Ocean's Thirteen"},
#  {'count': 122, 'year': 2009, 'title': 'The Stepfather'},
#  {'count': 122, 'year': 1994, 'title': 'The Shawshank Redemption'},
#  {'count': 122, 'year': 2003, 'title': 'The End of a Mystery'},
#  {'count': 122, 'year': 2009, 'title': 'Fighting'},
#  {'count': 121, 'year': 2005, 'title': 'Madagascar'},
#  {'count': 121, 'year': 1994, 'title': 'Pulp Fiction'},
#  {'count': 121, 'year': 1991, 'title': 'The Silence of the Lambs'},
#  {'count': 121, 'year': 2009, 'title': 'The Invention of Lying'},
#  {'count': 121, 'year': 2008, 'title': 'Quarantine'},
#  {'count': 121, 'year': 1998, 'title': "A Bug's Life"},
#  {'count': 121, 'year': 2009, 'title': 'G-Force'},
#  {'count': 120, 'year': 2003, 'title': 'Finding Nemo'},
#  {'count': 120, 'year': 1971, 'title': 'Willy Wonka & the Chocolate Factory'},
#  {'count': 119, 'year': 1995, 'title': 'Jumanji'},
#  {'count': 119, 'year': 1978, 'title': 'Grease'},
#  {'count': 119, 'year': 1999, 'title': '10 Things I Hate About You'},
#  {'count': 119, 'year': 2012, 'title': 'The Hunger Games'},
#  {'count': 119, 'year': 2005, 'title': 'Harry Potter and the Goblet of Fire'},
#  {'count': 119, 'year': 2009, 'title': 'Watchmen'},
#  {'count': 118, 'year': 1961, 'title': '101 Dalmatians'},
#  {'count': 117, 'year': 2005, 'title': 'Saw II'},
#  {'count': 117, 'year': 2012, 'title': 'The Avengers'},
#  {'count': 117,
#   'year': 2002,
#   'title': 'Star Wars: Episode II - Attack of the Clones'},
#  {'count': 117, 'year': 2009, 'title': 'Orphan'},
#  {'count': 116, 'year': 2003, 'title': 'Scary Movie 3'},
#  {'count': 116, 'year': 2003, 'title': 'Love Actually'},
#  {'count': 115, 'year': 1987, 'title': 'Dirty Dancing'},
#  {'count': 115,
#   'year': 1980,
#   'title': 'Star Wars: Episode V - The Empire Strikes Back'},
#  {'count': 115, 'year': 1990, 'title': 'Edward Scissorhands'},
#  {'count': 115,
#   'year': 2006,
#   'title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan'},
#  {'count': 115, 'year': 2006, 'title': 'The Departed'},
#  {'count': 115, 'year': 2001, 'title': 'Scary Movie 2'},
#  {'count': 115, 'year': 2003, 'title': 'How to Lose a Guy in 10 Days'},
#  {'count': 115, 'year': 2002, 'title': 'Sweet Home Alabama'},
#  {'count': 114,
#   'year': 2001,
#   'title': 'The Lord of the Rings: The Fellowship of the Ring'},
#  {'count': 114, 'year': 2007, 'title': 'Hairspray'},
#  {'count': 113, 'year': 2007, 'title': 'Disturbia'},
#  {'count': 111, 'year': 2009, 'title': 'District 9'},
#  {'count': 111, 'year': 2000, 'title': "Charlie's Angels"},
#  {'count': 111, 'year': 2007, 'title': 'American Gangster'},
#  {'count': 111, 'year': 2000, 'title': 'Coyote Ugly'},
#  {'count': 109, 'year': 2012, 'title': 'The Amazing Spider-Man'},
#  {'count': 108, 'year': 1992, 'title': 'Home Alone 2: Lost in New York'},
#  {'count': 107, 'year': 2007, 'title': 'Norbit'},
#  {'count': 5, 'year': 1995, 'title': 'The Cure'},
#  {'count': 4, 'year': 2010, 'title': 'Night Catches Us'},
#  {'count': 4, 'year': 2012, 'title': 'Compliance'},
#  {'count': 4, 'year': 1972, 'title': 'Play It Again, Sam'},
#  {'count': 4, 'year': 2009, 'title': 'Splice'},
#  {'count': 4,
#   'year': 2003,
#   'title': 'Cowards Bend the Knee or The Blue Hands'},
#  {'count': 4, 'year': 2008, 'title': 'The Women'},
#  {'count': 3, 'year': 2007, 'title': 'City of Men'},
#  {'count': 3, 'year': 2010, 'title': 'Date Night'},
#  {'count': 3, 'year': 1961, 'title': 'A Wife Confesses'},
#  {'count': 3, 'year': 2009, 'title': 'Cairo Time'},
#  {'count': 3, 'year': 1996, 'title': 'Moebius'},
#  {'count': 3, 'year': 2006, 'title': 'Comeback Season'},
#  {'count': 3, 'year': 1994, 'title': 'Pom Poko'},
#  {'count': 3, 'year': 1995, 'title': 'Forgotten Silver'},
#  {'count': 3, 'year': 2013, 'title': 'Metalhead'},
#  {'count': 3, 'year': 1960, 'title': 'The Apartment'},
#  {'count': 3, 'year': 1992, 'title': 'Christmas in Connecticut'},
#  {'count': 3, 'year': 2007, 'title': 'Exte: Hair Extensions'},
#  {'count': 3, 'year': 2014, 'title': 'Misconception'},
#  {'count': 3, 'year': 2015, 'title': 'Tired Moonlight'},
#  {'count': 3, 'year': 1985, 'title': 'Twice in a Lifetime'},
#  {'count': 3, 'year': 2004, 'title': 'Dig!'},
#  {'count': 3, 'year': 2010, 'title': 'Metrobranding'},
#  {'count': 3, 'year': 2015, 'title': 'The Shaman'},
#  {'count': 3, 'year': 1977, 'title': 'Roots'},
#  {'count': 3, 'year': 2009, 'title': 'Peter and Vandy'},
#  {'count': 3, 'year': 1988, 'title': 'High Spirits'},
#  {'count': 3, 'year': 1998, 'title': 'Return to Paradise'},
#  {'count': 3, 'year': 1927, 'title': 'Upstream'},
#  {'count': 3, 'year': 1992, 'title': 'The Mighty Ducks'},
#  {'count': 3, 'year': 2015, 'title': 'The Saboteurs'},
#  {'count': 3, 'year': 2011, 'title': 'Without Men'},
#  {'count': 3, 'year': 2015, 'title': '45 Years'},
#  {'count': 3, 'year': 2001, 'title': 'When Good Ghouls Go Bad'},
#  {'count': 3, 'year': 1964, 'title': 'King & Country'},
#  {'count': 3, 'year': 2012, 'title': 'Jesse Stone: Benefit of the Doubt'},
#  {'count': 3, 'year': 2009, 'title': 'The Dark House'},
#  {'count': 3, 'year': 2013, 'title': 'SAGA: Curse of the Shadow'},
#  {'count': 3, 'year': 1978, 'title': 'La Cage aux Folles'},
#  {'count': 3, 'year': 2001, 'title': 'The Rising Place'},
#  {'count': 3, 'year': 1972, 'title': 'Horror Express'},
#  {'count': 3, 'year': 1955, 'title': 'Footsteps in the Fog'},
#  {'count': 3, 'year': 1998, 'title': 'A True Mob Story'},
#  {'count': 3, 'year': 1983, 'title': 'Max Dugan Returns'},
#  {'count': 3, 'year': 1975, 'title': 'The Promised Land'},
#  {'count': 3, 'year': 2001, 'title': 'Jurassic Park III'},
#  {'count': 3, 'year': 2013, 'title': 'Monster High: Friday Night Frights'},
#  {'count': 3, 'year': 1965, 'title': 'The Cincinnati Kid'},
#  {'count': 3, 'year': 2011, 'title': 'Beauty Day'},
#  {'count': 3, 'year': 2013, 'title': 'Olympus Has Fallen'},
#  {'count': 3, 'year': 1999, 'title': 'Mystery Men'},
#  {'count': 3, 'year': 2009, 'title': 'Someone Like You'},
#  {'count': 3, 'year': 1963, 'title': 'Yesterday, Today and Tomorrow'},
#  {'count': 3, 'year': 2004, 'title': 'Ten Skies'},
#  {'count': 3, 'year': 1996, 'title': "Lilian's Story"},
#  {'count': 3, 'year': 2013, 'title': 'Stand Clear of the Closing Doors'},
#  {'count': 3, 'year': 2010, 'title': 'Pink Saris'},
#  {'count': 3, 'year': 1960, 'title': 'Midnight Lace'},
#  {'count': 3, 'year': 1976, 'title': 'The House by the Lake'},
#  {'count': 3, 'year': 2008, 'title': 'I Am So Proud of You'},
#  {'count': 3, 'year': 1997, 'title': 'The House'},
#  {'count': 3, 'year': 2000, 'title': 'Bonhoeffer: Agent of Grace'},
#  {'count': 3, 'year': 2003, 'title': 'Hitler: The Rise of Evil'},
#  {'count': 3, 'year': 2011, 'title': 'Bringing Ashley Home'},
#  {'count': 3, 'year': 2015, 'title': '3 1/2 Minutes, Ten Bullets'},
#  {'count': 3, 'year': 2000, 'title': "Everybody's Famous!"},
#  {'count': 3, 'year': 2010, 'title': 'Good Neighbors'},
#  {'count': 3, 'year': 2005, 'title': 'Kiss Kiss Bang Bang'},
#  {'count': 3, 'year': 2012, 'title': 'Lord of Darkness'},
#  {'count': 3, 'year': 2007, 'title': 'Epic Movie'},
#  {'count': 3, 'year': 1994, 'title': 'Federal Hill'},
#  {'count': 3, 'year': 2010, 'title': 'Great Migrations'},
#  {'count': 3, 'year': 1996, 'title': 'Drifting Clouds'},
#  {'count': 3, 'year': 2009, 'title': 'Obitaemyy ostrov. Skhvatka'},
#  {'count': 3, 'year': 1989, 'title': 'Cold Feet'},
#  {'count': 3, 'year': 1981, 'title': 'Duelul'},
#  {'count': 3, 'year': 2000, 'title': '3rd World Hero'},
#  {'count': 3, 'year': 2003, 'title': 'Proteus'},
#  {'count': 3, 'year': 1954, 'title': 'Chronicle of Poor Lovers'},
#  {'count': 3, 'year': 2006, 'title': 'Palimpsest'},
#  {'count': 3, 'year': 2014, 'title': 'Inherent Vice'},
#  {'count': 3, 'year': 1976, 'title': "That's Entertainment, Part II"},
#  {'count': 3, 'year': 1997, 'title': 'The Boxer'},
#  {'count': 3, 'year': 1977, 'title': 'Scott Joplin'},
#  {'count': 3, 'year': 1992, 'title': 'The Boys of St. Vincent'},
#  {'count': 3, 'year': 1990, 'title': 'Werner - Beinhart!'},
#  {'count': 3, 'year': 2006, 'title': 'The Valet'},
#  {'count': 3, 'year': 1949, 'title': "Occupe-toi d'Amèlie..!"},
#  {'count': 3, 'year': 2011, 'title': 'The Unknown Woman'},
#  {'count': 3, 'year': 1961, 'title': 'The Roman Spring of Mrs. Stone'},
#  {'count': 3, 'year': 2005, 'title': 'Wah-Wah'},
#  {'count': 3, 'year': 2010, 'title': 'The Dark Side of Chocolate'},
#  {'count': 3, 'year': 2013, 'title': 'American Courtesans'},
#  {'count': 3, 'year': 1972, 'title': 'Silent Running'},
#  {'count': 3, 'year': 2013, 'title': 'Gangster Squad'},
#  {'count': 3, 'year': 2005, 'title': 'Bionicle 3: Web of Shadows'},
#  {'count': 3, 'year': 1960, 'title': 'Macario'},
#  {'count': 3, 'year': 2010, 'title': 'Midnight FM'},
#  {'count': 3, 'year': 2006, 'title': 'Mr. Average'},
#  {'count': 3, 'year': 1996, 'title': "Dead Man's Walk"},
#  {'count': 3, 'year': 2006, 'title': 'Nacho Libre'},
#  {'count': 3, 'year': 1975, 'title': 'Euridice BA 2O37'},
#  {'count': 3, 'year': 1955, 'title': 'Taira Clan Saga'},
#  {'count': 3, 'year': 2014, 'title': 'Plastic'},
#  {'count': 3, 'year': 2010, 'title': 'Bleak Night'},
#  {'count': 3, 'year': 2004, 'title': 'Cube Zero'},
#  {'count': 3, 'year': 1968, 'title': "Je t'aime je t'aime"},
#  {'count': 3, 'year': 2010, 'title': "The King's Speech"},
#  {'count': 3, 'year': 2014, 'title': 'Cesar Chavez'},
#  {'count': 3, 'year': 1990, 'title': "Betsy's Wedding"},
#  {'count': 3, 'year': 2009, 'title': 'Bride Wars'},
#  {'count': 3, 'year': 1992, 'title': 'Honey I Blew Up the Kid'},
#  {'count': 3, 'year': 2009, 'title': 'Rabbit è la Berlin'},
#  {'count': 3, 'year': 1989, 'title': 'The Cow'},
#  {'count': 3, 'year': 2011, 'title': 'The Moth Diaries'},
#  {'count': 3, 'year': 2004, 'title': 'Black Cloud'},
#  {'count': 3, 'year': 2008, 'title': 'La buena nueva'},
#  {'count': 3, 'year': 1986, 'title': 'From Beyond'},
#  {'count': 3, 'year': 2001, 'title': 'Green Dragon'},
#  {'count': 3, 'year': 1999, 'title': 'Bartok the Magnificent'},
#  {'count': 3, 'year': 2006, 'title': 'Robin-B-Hood'},
#  {'count': 3, 'year': 1997, 'title': 'Amistad'},
#  {'count': 3, 'year': 1999, 'title': 'Deterrence'},
#  {'count': 3, 'year': 1971, 'title': 'Duck, You Sucker'},
#  {'count': 3, 'year': 1991, 'title': 'Black Robe'},
#  {'count': 3,
#   'year': 2014,
#   'title': 'Never Tear Us Apart: The Untold Story of INXS'},
#  {'count': 3, 'year': 1993, 'title': 'Return of the Living Dead III'},
#  {'count': 3, 'year': 2011, 'title': 'Overheard 2'},
#  {'count': 3, 'year': 1996, 'title': "Jackie Chan's First Strike"},
#  {'count': 3, 'year': 2000, 'title': 'Happenstance'},
#  {'count': 3, 'year': 2005, 'title': 'Syriana'},
#  {'count': 3, 'year': 2004, 'title': 'The Terminal'},
#  {'count': 3, 'year': 2006, 'title': 'Naming Number Two'},
#  {'count': 3, 'year': 2001, 'title': '61*'},
#  {'count': 3, 'year': 2014, 'title': 'They Are All Dead'},
#  {'count': 3, 'year': 2008, 'title': 'Batman: Gotham Knight'},
#  {'count': 3, 'year': 2014, 'title': 'Exists'},
#  {'count': 3, 'year': 2013, 'title': 'Jibeuro ganeun gil'},
#  {'count': 3, 'year': 2014, 'title': 'Nas: Time Is Illmatic'},
#  {'count': 3, 'year': 2004, 'title': 'The Motorcycle Diaries'},
#  {'count': 3, 'year': 2009, 'title': 'Slice'},
#  {'count': 3, 'year': 1997, 'title': 'Chile, the Obstinate Memory'},
#  {'count': 2, 'year': 1988, 'title': 'Beaches'},
#  {'count': 2, 'year': 1978, 'title': 'Midnight Express'},
#  {'count': 2, 'year': 2008, 'title': 'Faintheart'},
#  {'count': 2, 'year': 1969, 'title': 'The Unfaithful Wife'},
#  {'count': 2, 'year': 1999, 'title': 'Miss Julie'},
#  {'count': 2, 'year': 2005, 'title': 'BloodRayne'},
#  {'count': 2, 'year': 2012, 'title': 'Villegas'},
#  {'count': 2, 'year': 2001, 'title': 'Miss Minoes'},
#  {'count': 2, 'year': 2009, 'title': 'Sex, Party and Lies'},
#  {'count': 2, 'year': 1992, 'title': 'Como agua para chocolate'},
#  {'count': 2, 'year': 2014, 'title': 'White Bird in a Blizzard'},
#  {'count': 2, 'year': 2015, 'title': 'Dark Horse'},
#  {'count': 2, 'year': 2000, 'title': 'Crazy'},
#  {'count': 2, 'year': 2009, 'title': 'Carriers'},
#  {'count': 2, 'year': 2011, 'title': 'Source Code'},
#  {'count': 2, 'year': 2001, 'title': 'Soft Shell Man'},
#  {'count': 2, 'year': 2014, 'title': 'Erebus: Into the Unknown'},
#  {'count': 2, 'year': 1960, 'title': 'The Angry Silence'},
#  {'count': 2, 'year': 1962, 'title': 'Two for the Seesaw'},
#  {'count': 2, 'year': 1998, 'title': 'La vendedora de rosas'},
#  {'count': 2, 'year': 2004, 'title': "Dave Chappelle: For What It's Worth"},
#  {'count': 2, 'year': 2013, 'title': 'Lad: A Yorkshire Story'},
#  {'count': 2, 'year': 2000, 'title': 'Rated X'},
#  {'count': 2, 'year': 2006, 'title': "Charlotte's Web"},
#  {'count': 2, 'year': 1996, 'title': 'Charms Zwischenfèlle'},
#  {'count': 2, 'year': 2009, 'title': 'The Answer Man'},
#  {'count': 2, 'year': 2005, 'title': 'Pierrepoint: The Last Hangman'},
#  {'count': 2, 'year': 1989, 'title': 'Life and Nothing But'},
#  {'count': 2, 'year': 1999, 'title': 'Oxygen'},
#  {'count': 2, 'year': 1993, 'title': 'Fiorile'},
#  {'count': 2, 'year': 1991, 'title': 'Lucky Luke'},
#  {'count': 2, 'year': 2009, 'title': 'Mother and Child'},
#  {'count': 2, 'year': 1999, 'title': 'Pitkè kuuma kesè'},
#  {'count': 2, 'year': 1998, 'title': 'Heaven'},
#  {'count': 2, 'year': 2007, 'title': 'Juno'},
#  {'count': 2, 'year': 1987, 'title': 'The Witches of Eastwick'},
#  {'count': 2, 'year': 2008, 'title': 'Cop Dog'},
#  {'count': 2,
#   'year': 2005,
#   'title': "Marilyn Hotchkiss' Ballroom Dancing & Charm School"},
#  {'count': 2, 'year': 2008, 'title': 'The Bank Job'},
#  {'count': 2, 'year': 1969, 'title': 'Goyokin'},
#  {'count': 2, 'year': 1987, 'title': 'Blind Date'},
#  {'count': 2, 'year': 2013, 'title': 'The Returned'},
#  {'count': 2, 'year': 1974, 'title': 'The Clockmaker of St. Paul'},
#  {'count': 2, 'year': 1992, 'title': 'Unforgiven'},
#  {'count': 2, 'year': 2003, 'title': 'Eloise at the Plaza'},
#  {'count': 2, 'year': 2013, 'title': 'Commando'},
#  {'count': 2, 'year': 1959, 'title': 'Gidget'},
#  {'count': 2, 'year': 1996, 'title': 'Breathing Room'},
#  {'count': 2, 'year': 2010, 'title': 'Thirst'},
#  {'count': 2, 'year': 1950, 'title': 'The Magnificent Yankee'},
#  {'count': 2, 'year': 2000, 'title': 'What Lies Beneath'},
#  {'count': 2, 'year': 1981, 'title': 'Cattle Annie and Little Britches'},
#  {'count': 2, 'year': 2013, 'title': 'Locke'},
#  {'count': 2, 'year': 1989, 'title': 'Johnny Handsome'},
#  {'count': 2, 'year': 2013, 'title': 'Adult World'},
#  {'count': 2, 'year': 2000, 'title': 'Come Undone'},
#  {'count': 2, 'year': 1967, 'title': 'Barefoot in the Park'},
#  {'count': 2, 'year': 2013, 'title': 'Mystery Road'},
#  {'count': 2, 'year': 2006, 'title': 'Hacking Democracy'},
#  {'count': 2, 'year': 1997, 'title': 'Nil by Mouth'},
#  {'count': 2, 'year': 1950, 'title': 'The Munekata Sisters'},
#  {'count': 2, 'year': 2012, 'title': 'And While We Were Here'},
#  {'count': 2, 'year': 2008, 'title': 'Our Beloved Month of August'},
#  {'count': 2, 'year': 2008, 'title': 'Poppy Shakespeare'},
#  {'count': 2, 'year': 1980, 'title': 'The Age of the Earth'},
#  {'count': 2, 'year': 1999, 'title': 'Better Than Chocolate'},
#  {'count': 2, 'year': 2008, 'title': 'Disaster Movie'},
#  {'count': 2, 'year': 1987, 'title': 'The Untouchables'},
#  {'count': 2, 'year': 2001, 'title': 'Tremors 3: Back to Perfection'},
#  {'count': 2, 'year': 1997, 'title': 'Princess Mononoke'},
#  {'count': 2, 'year': 2001, 'title': 'Joy Ride'},
#  {'count': 2, 'year': 2008, 'title': 'Lyubov 2 Morkov'},
#  {'count': 2, 'year': 1991, 'title': 'Hors la vie'},
#  {'count': 2, 'year': 2014, 'title': 'The Book of Life'},
#  {'count': 2, 'year': 2003, 'title': 'The Pentagon Papers'},
#  {'count': 2, 'year': 1983, 'title': 'The Story of Piera'},
#  {'count': 2,
#   'year': 2001,
#   'title': 'Mermaid Chronicles Part 1: She Creature'},
#  {'count': 2, 'year': 1988, 'title': 'Alien Nation'},
#  {'count': 2, 'year': 2001, 'title': 'Jeepers Creepers'},
#  {'count': 2, 'year': 2013, 'title': 'Beautiful Creatures'},
#  {'count': 2, 'year': 1965, 'title': 'Three'},
#  {'count': 2, 'year': 2015, 'title': 'Bitva za Sevastopol'},
#  {'count': 2, 'year': 2005, 'title': 'Keep Your Distance'},
#  {'count': 2, 'year': 2011, 'title': 'Volcano'},
#  {'count': 2, 'year': 2005, 'title': 'Wedding Chest'},
#  {'count': 2, 'year': 2015, 'title': 'Larry Kramer in Love and Anger'},
#  {'count': 2, 'year': 2001, 'title': 'Visitor Q'},
#  {'count': 2, 'year': 2004, 'title': 'Ryan'},
#  {'count': 2, 'year': 2004, 'title': 'Hawaii, Oslo'},
#  {'count': 2, 'year': 2014, 'title': 'We Are Young. We Are Strong.'},
#  {'count': 2, 'year': 1999, 'title': 'Luna Papa'},
#  {'count': 2, 'year': 1972, 'title': 'Schoolgirls Growing Up'},
#  {'count': 2, 'year': 2010, 'title': 'Hatchet II'},
#  {'count': 2, 'year': 1988, 'title': 'Mississippi Burning'},
#  {'count': 2, 'year': 1999, 'title': 'Life, Autumn'},
#  {'count': 2, 'year': 2013, 'title': 'American Promise'},
#  {'count': 2, 'year': 2013, 'title': 'The Blue Umbrella'},
#  {'count': 2, 'year': 2013, 'title': "Jodorowsky's Dune"},
#  {'count': 2, 'year': 1997, 'title': 'Sue'},
#  {'count': 2, 'year': 1967, 'title': 'Blood River'},
#  {'count': 2, 'year': 1990, 'title': 'Reversal of Fortune'},
#  {'count': 2, 'year': 1996, 'title': 'The First Wives Club'},
#  {'count': 2, 'year': 2012, 'title': 'No Place on Earth'},
#  {'count': 2, 'year': 2001, 'title': 'Lucky Break'},
#  {'count': 2, 'year': 2015, 'title': 'Equals'},
#  {'count': 2, 'year': 2013, 'title': 'Min sèsters bèrn i Afrika'},
#  {'count': 2, 'year': 1997, 'title': 'Mrs Dalloway'},
#  {'count': 2, 'year': 1970, 'title': 'Pieces of Dreams'},
#  {'count': 2, 'year': 2008, 'title': 'Kacheli'},
#  {'count': 2, 'year': 2004, 'title': 'Torque'},
#  {'count': 2, 'year': 2008, 'title': 'Sorry for the Disturbance'},
#  {'count': 2, 'year': 2006, 'title': 'Running Scared'},
#  {'count': 2, 'year': 1989, 'title': 'Ghostbusters II'},
#  {'count': 2, 'year': 2013, 'title': 'Baggage Claim'},
#  {'count': 2, 'year': 1982, 'title': 'Twilight Time'},
#  {'count': 2, 'year': 2005, 'title': 'Crazy for Christmas'},
#  {'count': 2, 'year': 1926, 'title': 'The Strong Man'},
#  {'count': 2, 'year': 1962, 'title': '40 Pounds of Trouble'},
#  {'count': 2, 'year': 2012, 'title': 'Ted'},
#  {'count': 2, 'year': 2007, 'title': 'Chaotic Ana'},
#  {'count': 2, 'year': 1956, 'title': 'The Catered Affair'},
#  {'count': 2, 'year': 2005, 'title': 'Corpse Bride'},
#  {'count': 2, 'year': 1995, 'title': 'Kristin Lavransdatter'},
#  {'count': 2,
#   'year': 2013,
#   'title': 'Temptation: Confessions of a Marriage Counselor'},
#  {'count': 2, 'year': 2015, 'title': 'Dreamcatcher'},
#  {'count': 2, 'year': 1975, 'title': 'Monty Python and the Holy Grail'},
#  {'count': 2, 'year': 1999, 'title': 'Second Skin'},
#  {'count': 2, 'year': 2007, 'title': 'Shotgun Stories'},
#  {'count': 2, 'year': 2007, 'title': 'Om Shanti Om'},
#  {'count': 2, 'year': 2000, 'title': 'The Endurance'},
#  {'count': 2, 'year': 2003, 'title': 'Bodysong'},
#  {'count': 2, 'year': 1988, 'title': 'The Kiss'},
#  {'count': 2, 'year': 1972, 'title': 'Slaughterhouse-Five'},
#  {'count': 2, 'year': 2008, 'title': 'Snakes and Earrings'},
#  {'count': 2, 'year': 1999, 'title': "Lord's Lantern in Budapest"},
#  {'count': 2, 'year': 2013, 'title': 'Motylki'},
#  {'count': 2, 'year': 1998, 'title': 'Goodnight, Mister Tom'},
#  {'count': 2, 'year': 2011, 'title': 'Goon'},
#  {'count': 2, 'year': 2013, 'title': 'Ambassada'},
#  {'count': 2, 'year': 1997, 'title': 'Face/Off'},
#  {'count': 2, 'year': 2006, 'title': 'Choking Man'},
#  {'count': 2, 'year': 2015, 'title': '600 Millas'},
#  {'count': 2, 'year': 1954, 'title': 'Brigadoon'},
#  {'count': 2,
#   'year': 2009,
#   'title': 'Genius Within: The Inner Life of Glenn Gould'},
#  {'count': 2, 'year': 2013, 'title': "The Butterfly's Dream"},
#  {'count': 2, 'year': 1987, 'title': 'Rouge'},
#  {'count': 2, 'year': 2005, 'title': 'China Blue'},
#  {'count': 2, 'year': 2004, 'title': 'Downfall'},
#  {'count': 2, 'year': 2010, 'title': 'Nokas'},
#  {'count': 2, 'year': 1989, 'title': 'Balance'},
#  {'count': 2, 'year': 1990, 'title': "Child's Play 2"},
#  {'count': 2, 'year': 1981, 'title': 'S.O.B.'},
#  {'count': 2, 'year': 2008, 'title': 'Female Agents'},
#  {'count': 2, 'year': 1978, 'title': 'Remember My Name'},
#  {'count': 2, 'year': 1985, 'title': 'Return to Oz'},
#  {'count': 2, 'year': 2012, 'title': 'Isdraken'},
#  {'count': 2, 'year': 2006, 'title': "Pao's Story"},
#  {'count': 2, 'year': 1968, 'title': 'Charly'},
#  {'count': 2, 'year': 2013, 'title': 'Hansel & Gretel: Witch Hunters'},
#  {'count': 2, 'year': 2002, 'title': 'Sammy and Me'},
#  {'count': 2, 'year': 2003, 'title': 'Kopps'},
#  {'count': 2, 'year': 1971, 'title': 'Joe Hill'},
#  {'count': 2, 'year': 2006, 'title': 'End Game'},
#  {'count': 2, 'year': 1975, 'title': 'Xala'},
#  {'count': 2, 'year': 2001, 'title': 'Jesus Christ Vampire Hunter'},
#  {'count': 2,
#   'year': 2015,
#   'title': 'B-Movie: Lust & Sound in West-Berlin 1979-1989'},
#  {'count': 2, 'year': 2012, 'title': 'Small Apartments'},
#  {'count': 2, 'year': 2013, 'title': "Fanie Fourie's Lobola"},
#  {'count': 2, 'year': 2009, 'title': 'Ruhr'},
#  {'count': 2, 'year': 2005, 'title': 'Last Days'},
#  {'count': 2, 'year': 2007, 'title': 'Appleseed Saga: Ex Machina'},
#  {'count': 2, 'year': 2008, 'title': 'The Clone Returns Home'},
#  {'count': 2, 'year': 2011, 'title': 'How to Stop Being a Loser'},
#  {'count': 2, 'year': 2010, 'title': 'Sweet Evil'},
#  {'count': 2, 'year': 2002, 'title': '24 Hour Party People'},
#  {'count': 2, 'year': 1993, 'title': 'Patlabor 2: The Movie'},
#  {'count': 2, 'year': 2013, 'title': 'Sword Art Online Extra Edition'},
#  {'count': 2, 'year': 2012, 'title': 'Mann tut was Mann kann'},
#  {'count': 2, 'year': 2013, 'title': 'The Terror Live'},
#  {'count': 2, 'year': 2009, 'title': 'An Englishman in New York'},
#  {'count': 2, 'year': 2000, 'title': 'The Art of War'},
#  {'count': 2, 'year': 2001, 'title': 'Me and Morrison'},
#  {'count': 2,
#   'year': 2009,
#   'title': 'Monsters vs Aliens: Mutant Pumpkins from Outer Space'},
#  {'count': 2, 'year': 2006, 'title': 'Step Up'},
#  {'count': 2, 'year': 2011, 'title': 'Girl Fight'},
#  {'count': 2, 'year': 2007, 'title': 'Shadows'},
#  {'count': 2, 'year': 2014, 'title': 'Cruel & Unusual'},
#  {'count': 2, 'year': 2003, 'title': 'The Medallion'},
#  {'count': 2, 'year': 1994, 'title': 'Lakota Woman: Siege at Wounded Knee'},
#  {'count': 2, 'year': 2014, 'title': 'A Brilliant Young Mind'},
#  {'count': 2, 'year': 2009, 'title': 'Precious'},
#  {'count': 2, 'year': 2010, 'title': 'Due Date'},
#  {'count': 2, 'year': 1957, 'title': "A Tailor's Maid"},
#  {'count': 2, 'year': 1963, 'title': 'The Caretakers'},
#  {'count': 2, 'year': 2002, 'title': 'Love in the Time of Money'},
#  {'count': 2, 'year': 1997, 'title': 'Blackrock'},
#  {'count': 2, 'year': 2013, 'title': 'West'},
#  {'count': 2, 'year': 1996, 'title': 'The Last of the High Kings'},
#  {'count': 2, 'year': 2006, 'title': 'Priceless'},
#  {'count': 2, 'year': 2014, 'title': 'Songs She Wrote About People She Knows'},
#  {'count': 2, 'year': 1983, 'title': 'The Moon in the Gutter'},
#  {'count': 2, 'year': 2008, 'title': 'Suspect X'},
#  {'count': 2, 'year': 1997, 'title': 'What the Deaf Man Heard'},
#  {'count': 2, 'year': 2005, 'title': 'Cinderella Man'},
#  {'count': 2, 'year': 1997, 'title': 'Warriors of Virtue'},
#  {'count': 2, 'year': 1992, 'title': "I Don't Buy Kisses Anymore"},
#  {'count': 2, 'year': 1989, 'title': 'Cannonball Fever'},
#  {'count': 2, 'year': 2010, 'title': 'Jitters'},
#  {'count': 2, 'year': 1991, 'title': 'Den ofrivillige golfaren'},
#  {'count': 2, 'year': 1966, 'title': 'Alfie'},
#  {'count': 2,
#   'year': 1988,
#   'title': 'Police Academy 5: Assignment: Miami Beach'},
#  {'count': 2, 'year': 2007, 'title': 'Anna M.'},
#  {'count': 2, 'year': 1935, 'title': 'China Seas'},
#  {'count': 2, 'year': 2001, 'title': 'Delbaran'},
#  {'count': 2, 'year': 2000, 'title': 'The Amati Girls'},
#  {'count': 2, 'year': 2010, 'title': 'Four Days Inside Guantanamo'},
#  {'count': 2, 'year': 2014, 'title': 'Black Souls'},
#  {'count': 2, 'year': 1992, 'title': 'Shining Through'},
#  {'count': 2, 'year': 2013, 'title': 'Leave to Remain'},
#  {'count': 2, 'year': 1978, 'title': 'Don'},
#  {'count': 2, 'year': 2002, 'title': 'Devdas'},
#  {'count': 2, 'year': 1999, 'title': 'Catfish in Black Bean Sauce'},
#  {'count': 2, 'year': 2011, 'title': 'Century of Birthing'},
#  {'count': 2, 'year': 2007, 'title': 'Lars and the Real Girl'},
#  {'count': 2, 'year': 1975, 'title': 'The Wind and the Lion'},
#  {'count': 2, 'year': 1986, 'title': 'Big Trouble in Little China'},
#  {'count': 2, 'year': 2010, 'title': 'Tooth Fairy'},
#  {'count': 2, 'year': 2005, 'title': '3è kèlter'},
#  {'count': 2, 'year': 2000, 'title': 'Dirty Pictures'},
#  {'count': 2, 'year': 2013, 'title': 'Mèbius'},
#  {'count': 2, 'year': 1989, 'title': 'Cheetah'},
#  {'count': 2, 'year': 1999, 'title': 'The Bridge'},
#  {'count': 2, 'year': 2011, 'title': 'Savage'},
#  {'count': 2, 'year': 2007, 'title': 'Jack Brooks: Monster Slayer'},
#  {'count': 2, 'year': 1968, 'title': 'No Path Through Fire'},
#  {'count': 2, 'year': 2006, 'title': 'Mentor'},
#  {'count': 2, 'year': 2004, 'title': 'Miracle'},
#  {'count': 2, 'year': 2007, 'title': 'Ya ostayus'},
#  {'count': 2, 'year': 1988, 'title': 'Waxwork'},
#  {'count': 2, 'year': 1970, 'title': 'The Breach'},
#  {'count': 2, 'year': 2004, 'title': 'The Bridesmaid'},
#  {'count': 2, 'year': 1998, 'title': 'The Big Lebowski'},
#  {'count': 2, 'year': 1971, 'title': 'The French Connection'},
#  {'count': 2, 'year': 2010, 'title': 'Somewhere'},
#  {'count': 2, 'year': 1998, 'title': 'Pocahontas II: Journey to a New World'},
#  {'count': 2, 'year': 2008, 'title': 'Igor'},
#  {'count': 2, 'year': 1995, 'title': 'Dead Presidents'},
#  {'count': 2, 'year': 2000, 'title': 'Battlefield Earth'},
#  {'count': 2,
#   'year': 2004,
#   'title': 'Anacondas: The Hunt for the Blood Orchid'},
#  {'count': 2, 'year': 2011, 'title': 'Hell and Back Again'},
#  {'count': 2, 'year': 1999, 'title': 'Kiss Me in the Rain'},
#  {'count': 2, 'year': 2009, 'title': 'Nowhere Boy'},
#  {'count': 2, 'year': 2013, 'title': 'Unbeatable'},
#  {'count': 2, 'year': 2000, 'title': 'Crime + Punishment in Suburbia'},
#  {'count': 2, 'year': 2006, 'title': 'The Fox and the Hound 2'},
#  {'count': 2, 'year': 2014, 'title': "I'm the One You Want"},
#  {'count': 2, 'year': 2001, 'title': 'Ghost World'},
#  {'count': 2, 'year': 1990, 'title': 'Die Hard 2'},
#  {'count': 2, 'year': 2014, 'title': 'Fort Tilden'},
#  {'count': 2, 'year': 2012, 'title': 'S#x Acts'},
#  {'count': 2, 'year': 1989, 'title': 'Parenthood'},
#  {'count': 2, 'year': 2004, 'title': 'Bridget Jones: The Edge of Reason'},
#  {'count': 2, 'year': 2011, 'title': 'Girl Walks Into a Bar'},
#  {'count': 2, 'year': 2001, 'title': 'Aalavandhan'},
#  {'count': 2, 'year': 2004, 'title': 'Ab Tak Chhappan'},
#  {'count': 2, 'year': 1992, 'title': 'Scent of a Woman'},
#  {'count': 2, 'year': 2004, 'title': 'Catch That Kid'},
#  {'count': 2, 'year': 1985, 'title': 'Police Story'},
#  {'count': 2, 'year': 2006, 'title': 'The Illusionist'},
#  {'count': 2, 'year': 2001, 'title': 'Transistor Love Story'},
#  {'count': 2, 'year': 1989, 'title': 'Noce blanche'},
#  {'count': 2, 'year': 2013, 'title': 'Amiche da morire'},
#  {'count': 2, 'year': 1957, 'title': 'Will Success Spoil Rock Hunter?'},
#  {'count': 2, 'year': 2010, 'title': 'Inside Job'},
#  {'count': 2, 'year': 2014, 'title': '20,000 Days on Earth'},
#  {'count': 2, 'year': 1996, 'title': 'Deadly Voyage'},
#  {'count': 2, 'year': 1990, 'title': 'Heaven and Earth'},
#  {'count': 2, 'year': 2013, 'title': 'My Sweet Pepper Land'},
#  {'count': 2, 'year': 2005, 'title': 'Match Point'},
#  {'count': 2, 'year': 2015, 'title': 'Bessie'},
#  {'count': 2, 'year': 1994, 'title': "Nobody's Fool"},
#  {'count': 2, 'year': 2011, 'title': 'The Giants'},
#  {'count': 2, 'year': 2012, 'title': 'Dead Man Talking'},
#  {'count': 2, 'year': 2011, 'title': 'Familiar Grounds'},
#  {'count': 2, 'year': 2011, 'title': 'The Eagle'},
#  {'count': 2, 'year': 2010, 'title': 'How Do You Know'},
#  {'count': 2, 'year': 1948, 'title': 'Road House'},
#  {'count': 2, 'year': 2004, 'title': "We Don't Live Here Anymore"},
#  {'count': 2, 'year': 2007, 'title': 'Boy A'},
#  {'count': 2,
#   'year': 2007,
#   'title': 'The Land Before Time XIII: The Wisdom of Friends'},
#  {'count': 2, 'year': 2013, 'title': "Devil's Pass"},
#  {'count': 2, 'year': 2006, 'title': 'Local Color'},
#  {'count': 2, 'year': 1971, 'title': 'The Policeman'},
#  {'count': 2, 'year': 2013, 'title': 'The Wizards Return: Alex vs. Alex'},
#  {'count': 2, 'year': 1977, 'title': 'The Rescuers'},
#  {'count': 2,
#   'year': 1989,
#   'title': 'The Toxic Avenger Part III: The Last Temptation of Toxie'},
#  {'count': 2, 'year': 2002, 'title': 'Enough'},
#  {'count': 2, 'year': 2012, 'title': 'To Rome with Love'},
#  {'count': 2, 'year': 2001, 'title': 'Pulse'},
#  {'count': 2, 'year': 2015, 'title': 'The Adderall Diaries'},
#  {'count': 2, 'year': 2014, 'title': 'PK'},
#  {'count': 2, 'year': 2009, 'title': 'Little Girl'},
#  {'count': 2, 'year': 2012, 'title': 'Iron Sky'},
#  {'count': 2, 'year': 2001, 'title': 'Truly Human'},
#  {'count': 2, 'year': 2013, 'title': 'Sleeping with the Fishes'},
#  {'count': 2, 'year': 1988, 'title': 'The House on Carroll Street'},
#  {'count': 2, 'year': 1991, 'title': 'Kafka'},
#  {'count': 2, 'year': 2014, 'title': 'Sand Castles'},
#  {'count': 2, 'year': 2007, 'title': 'Redacted'},
#  {'count': 2, 'year': 1990, 'title': 'Spontaneous Combustion'},
#  {'count': 2, 'year': 1996, 'title': 'My Entire Life'},
#  {'count': 2, 'year': 2010, 'title': "I'm Still Here"},
#  {'count': 2, 'year': 1958, 'title': 'Ride a Crooked Trail'},
#  {'count': 2, 'year': 2005, 'title': 'Quo Vadis, Baby?'},
#  {'count': 2, 'year': 2002, 'title': 'Two Weeks Notice'},
#  {'count': 2, 'year': 1980, 'title': 'Rude Boy'},
#  {'count': 2, 'year': 2004, 'title': 'Head in the Clouds'},
#  {'count': 2, 'year': 2012, 'title': 'The Floating Castle'},
#  {'count': 2, 'year': 2011, 'title': 'Red Riding Hood'},
#  {'count': 2, 'year': 2005, 'title': 'Bewitched'},
#  {'count': 2, 'year': 2012, 'title': 'Moonrise Kingdom'},
#  {'count': 2, 'year': 2014, 'title': 'Concerning Violence'},
#  {'count': 2, 'year': 1949, 'title': 'Rosvo Roope'},
#  {'count': 2, 'year': 2003, 'title': 'Thirteen'},
#  {'count': 2, 'year': 2001, 'title': "Varian's War"},
#  {'count': 2, 'year': 1991, 'title': "I Don't Kiss"},
#  {'count': 2, 'year': 2011, 'title': 'My Tomorrow'},
#  {'count': 2, 'year': 1943, 'title': 'Victory Through Air Power'},
#  {'count': 2, 'year': 1988, 'title': 'Action Jackson'},
#  {'count': 2, 'year': 2007, 'title': 'Eye in the Sky'},
#  {'count': 2, 'year': 2011, 'title': 'Summer Games'},
#  {'count': 2, 'year': 2015, 'title': 'Ex Machina'},
#  {'count': 2, 'year': 1982, 'title': 'Six Weeks'},
#  {'count': 2, 'year': 2007, 'title': 'City of Men'},
#  {'count': 2, 'year': 1994, 'title': 'Zamok'},
#  {'count': 2, 'year': 2003, 'title': 'Detention'},
#  {'count': 2, 'year': 2014, 'title': 'Houdini'},
#  {'count': 2, 'year': 2013, 'title': 'Teenage'},
#  {'count': 2, 'year': 2004, 'title': 'The Whole Ten Yards'},
#  {'count': 2, 'year': 1972, 'title': 'The Carey Treatment'},
#  {'count': 2, 'year': 2011, 'title': 'The Awakening'},
#  {'count': 2, 'year': 1985, 'title': 'The Dirt Bike Kid'},
#  {'count': 2, 'year': 2010, 'title': "Bill Maher... But I'm Not Wrong"},
#  {'count': 2, 'year': 2014, 'title': 'Once Upon a Time in Shanghai'},
#  {'count': 2, 'year': 1956, 'title': 'Attack'},
#  {'count': 2, 'year': 2007, 'title': 'Cèo Sem Dono'},
#  {'count': 2, 'year': 2012, 'title': '009 Re: Cyborg'},
#  {'count': 2, 'year': 1958, 'title': 'The Naked and the Dead'},
#  {'count': 2, 'year': 1990, 'title': 'Goodfellas'},
#  {'count': 2,
#   'year': 2008,
#   'title': 'The Crimson Wing: Mystery of the Flamingos'},
#  {'count': 2, 'year': 2010, 'title': 'White Lion'},
#  {'count': 2, 'year': 2001, 'title': 'Bungee Jumping of Their Own'},
#  {'count': 2, 'year': 1972, 'title': 'Frenzy'},
#  {'count': 2, 'year': 1987, 'title': 'Julia and Julia'},
#  {'count': 2, 'year': 2007, 'title': 'Exodus'},
#  {'count': 2, 'year': 2013, 'title': 'Ek Thi Daayan'},
#  {'count': 2, 'year': 2004, 'title': 'Toolbox Murders'},
#  {'count': 2, 'year': 2007, 'title': 'The Mugger'},
#  {'count': 2, 'year': 2007, 'title': 'Nocturna'},
#  {'count': 2, 'year': 2005, 'title': "Refugee All Stars, Sierra Leone's"},
#  {'count': 2, 'year': 1988, 'title': 'Cocktail'},
#  {'count': 2, 'year': 1957, 'title': 'Sissi: The Fateful Years of an Empress'},
#  {'count': 2, 'year': 2005, 'title': 'Melissa P.'},
#  {'count': 2, 'year': 2008, 'title': 'Rozygrysh'},
#  {'count': 2, 'year': 2002, 'title': 'Sorority Boys'},
#  {'count': 2, 'year': 2008, 'title': '21'},
#  {'count': 2, 'year': 1999, 'title': 'Jesus Is a Palestinian'},
#  {'count': 2, 'year': 2007, 'title': 'Interview'},
#  {'count': 2, 'year': 1999, 'title': 'The Tough Ones'},
#  {'count': 2, 'year': 2010, 'title': 'Auk Nr. 8'},
#  {'count': 2, 'year': 2010, 'title': 'Bes Sehir'},
#  {'count': 2, 'year': 1955, 'title': 'The Prisoner'},
#  {'count': 2, 'year': 2014, 'title': 'The Theory of Everything'},
#  {'count': 2, 'year': 1956, 'title': 'Crashing Las Vegas'},
#  {'count': 2, 'year': 2011, 'title': 'Himizu'},
#  {'count': 2, 'year': 1970, 'title': 'Run, Simon, Run'},
#  {'count': 2, 'year': 2012, 'title': 'Zarafa'},
#  {'count': 2, 'year': 2011, 'title': 'Tom and Jerry & The Wizard of Oz'},
#  {'count': 2, 'year': 2011, 'title': 'Stopped on Track'},
#  {'count': 2, 'year': 2000, 'title': 'Urbania'},
#  {'count': 2, 'year': 1998, 'title': 'The Siege'},
#  {'count': 2, 'year': 1993, 'title': 'Wandering Sagittarius'},
#  {'count': 2, 'year': 1981, 'title': 'Lola'},
#  {'count': 2, 'year': 2009, 'title': 'Overheard'},
#  {'count': 2, 'year': 2013, 'title': "Thou Gild'st the Even"},
#  {'count': 2, 'year': 2015, 'title': 'Im Sommer wohnt er unten'},
#  {'count': 2, 'year': 2002, 'title': 'Raising Victor Vargas'},
#  {'count': 2, 'year': 1953, 'title': 'The Adultress'},
#  {'count': 2, 'year': 2014, 'title': 'Imperial Dreams'},
#  {'count': 2, 'year': 1974, 'title': 'Martha'},
#  {'count': 2, 'year': 1979, 'title': 'The Great Santini'},
#  {'count': 2, 'year': 2015, 'title': 'Night Owls'},
#  {'count': 2, 'year': 1983, 'title': 'The Black Stallion Returns'},
#  {'count': 2, 'year': 1996, 'title': 'Black Mask'},
#  {'count': 2, 'year': 2008, 'title': 'Yesterday Was a Lie'},
#  {'count': 2, 'year': 2008, 'title': "What Doesn't Kill You"},
#  {'count': 2, 'year': 1990, 'title': 'Jekyll & Hyde'},
#  {'count': 2, 'year': 1991, 'title': 'Mississippi Masala'},
#  {'count': 2, 'year': 2007, 'title': '99 francs'},
#  {'count': 2, 'year': 2001, 'title': "The Devil's Backbone"},
#  {'count': 2, 'year': 1977, 'title': 'The King of the Street Cleaners'},
#  {'count': 2, 'year': 1996, 'title': 'Flirting with Disaster'},
#  {'count': 2, 'year': 2003, 'title': 'A House Built on Water'},
#  {'count': 2, 'year': 1990, 'title': 'Eating'},
#  {'count': 2, 'year': 2014, 'title': 'The Homesman'},
#  {'count': 2, 'year': 2004, 'title': 'Noise'},
#  {'count': 2, 'year': 2005, 'title': 'Middle Sexes: Redefining He and She'},
#  {'count': 2, 'year': 1952, 'title': 'Room for One More'},
#  {'count': 2, 'year': 1996, 'title': 'Freeway'},
#  {'count': 2, 'year': 2012, 'title': 'No'},
#  {'count': 2, 'year': 2003, 'title': 'Latter Days'},
#  {'count': 2, 'year': 1988, 'title': 'Short Circuit 2'},
#  {'count': 2, 'year': 2013, 'title': 'Little Hope Was Arson'},
#  {'count': 2, 'year': 2000, 'title': 'Animal Factory'},
#  {'count': 2, 'year': 1970, 'title': 'The Out of Towners'},
#  {'count': 2, 'year': 2009, 'title': 'Phobia 2'},
#  {'count': 2, 'year': 2009, 'title': "We Don't Care About Music Anyway"},
#  {'count': 2, 'year': 2010, 'title': 'Dear Guest, When Will You Leave?'},
#  {'count': 2, 'year': 1957, 'title': 'Love in the Afternoon'},
#  {'count': 2, 'year': 1995, 'title': 'Nine Months'},
#  {'count': 2, 'year': 1996, 'title': 'Beautiful Girls'},
#  {'count': 2, 'year': 1984, 'title': 'Against All Odds'},
#  {'count': 2, 'year': 1960, 'title': 'Cinderfella'},
#  {'count': 2, 'year': 1973, 'title': 'Oklahoma Crude'},
#  {'count': 2, 'year': 1987, 'title': 'Wings of Desire'},
#  {'count': 2, 'year': 1998, 'title': 'Jack Frost'},
#  {'count': 2, 'year': 2014, 'title': 'Sabotage'},
#  {'count': 2, 'year': 1984, 'title': 'Where the Green Ants Dream'},
#  {'count': 2, 'year': 2005, 'title': 'Verlengd weekend'},
#  {'count': 2, 'year': 2001, 'title': 'The Road to Love'},
#  {'count': 2, 'year': 1995, 'title': 'Black Day Blue Night'},
#  {'count': 2, 'year': 2001, 'title': 'Princess Arete'},
#  {'count': 2, 'year': 2002, 'title': 'The Salton Sea'},
#  {'count': 2, 'year': 2007, 'title': 'The Life of Buddha'},
#  {'count': 2, 'year': 1999, 'title': 'All the Rage'},
#  {'count': 2, 'year': 2007, 'title': 'Our Town'},
#  {'count': 2, 'year': 1998, 'title': 'Some Girl'},
#  {'count': 2, 'year': 2015, 'title': 'Above and Below'},
#  {'count': 2, 'year': 2006, 'title': 'Destiny'},
#  {'count': 2, 'year': 2012, 'title': 'The Lucky One'},
#  {'count': 2, 'year': 1996, 'title': 'Shiloh'},
#  {'count': 2, 'year': 1995, 'title': 'The Mangler'},
#  {'count': 2, 'year': 1995, 'title': 'Fresh Bait'},
#  {'count': 2, 'year': 2000, 'title': 'Our Song'},
#  {'count': 2, 'year': 2006, 'title': 'Venus'},
#  {'count': 2, 'year': 1984, 'title': 'The River'},
#  {'count': 2, 'year': 2006, 'title': 'Lady in the Water'},
#  {'count': 2, 'year': 2006, 'title': "The Tiger's Tail"},
#  {'count': 2, 'year': 1998, 'title': 'Beefcake'},
#  {'count': 2, 'year': 2013, 'title': 'The Numbers Station'},
#  {'count': 2, 'year': 2005, 'title': "Winky's Horse"},
#  {'count': 2, 'year': 2012, 'title': 'Motorway'},
#  {'count': 2, 'year': 1989, 'title': 'Sweetie'},
#  {'count': 2, 'year': 2010, 'title': 'Jack Goes Boating'},
#  {'count': 2, 'year': 1948, 'title': 'Yoru no onnatachi'},
#  {'count': 2, 'year': 1975, 'title': 'Dog Day Afternoon'},
#  {'count': 2, 'year': 1995, 'title': 'Panther'},
#  {'count': 2, 'year': 1981, 'title': 'Passion of Love'},
#  {'count': 2, 'year': 2003, 'title': 'Star Runner'},
#  {'count': 2, 'year': 1988, 'title': 'Twins'},
#  {'count': 2,
#   'year': 1993,
#   'title': 'The Wonderful, Horrible Life of Leni Riefenstahl'},
#  {'count': 2, 'year': 2007, 'title': 'Drive Thru'},
#  {'count': 2, 'year': 2000, 'title': 'The Goddess of 1967'},
#  {'count': 2, 'year': 1996, 'title': 'Primal Fear'},
#  {'count': 2, 'year': 2001, 'title': 'Kabhi Khushi Kabhie Gham...'},
#  {'count': 2,
#   'year': 2005,
#   'title': "I'm King Kong!: The Exploits of Merian C. Cooper"},
#  {'count': 2, 'year': 1996, 'title': 'The Paper Brigade'},
#  {'count': 2, 'year': 1999, 'title': 'Tuesdays with Morrie'},
#  {'count': 2, 'year': 2015, 'title': "This Isn't Funny"},
#  {'count': 2, 'year': 1995, 'title': 'Two Deaths'},
#  {'count': 2, 'year': 1990, 'title': "Jacob's Ladder"},
#  {'count': 2, 'year': 2000, 'title': 'Faithless'},
#  {'count': 2, 'year': 1989, 'title': 'Common Threads: Stories from the Quilt'},
#  {'count': 2, 'year': 2014, 'title': 'The Journey'},
#  {'count': 2, 'year': 2014, 'title': 'One-Minute Time Machine'},
#  {'count': 2, 'year': 1938, 'title': "You Can't Take It With You"},
#  {'count': 2, 'year': 1988, 'title': 'Niezwykla podrèz Baltazara Kobera'},
#  {'count': 2, 'year': 2002, 'title': '9/11'},
#  {'count': 2, 'year': 2000, 'title': 'Brother'},
#  {'count': 2, 'year': 2012, 'title': 'Mars et Avril'},
#  {'count': 2, 'year': 2014, 'title': 'Whisper If I Forget'},
#  {'count': 2, 'year': 2010, 'title': 'Pyaar Impossible!'},
#  {'count': 2, 'year': 1977, 'title': 'Between the Lines'},
#  {'count': 2, 'year': 1937, 'title': 'Night Must Fall'},
#  {'count': 2, 'year': 2000, 'title': 'The 6th Day'},
#  {'count': 2, 'year': 2007, 'title': 'Autohystoria'},
#  {'count': 2, 'year': 1978, 'title': 'Interiors'},
#  {'count': 2, 'year': 2007, 'title': 'Pathfinder'},
#  {'count': 2, 'year': 1942, 'title': 'Yankee Doodle Dandy'},
#  {'count': 2, 'year': 2004, 'title': 'Lucky Luke and the Daltons'},
#  {'count': 2, 'year': 2006, 'title': 'Khottabych'},
#  {'count': 2, 'year': 2015, 'title': 'The Lobster'},
#  {'count': 2, 'year': 1999, 'title': 'Grizzly Falls'},
#  {'count': 2, 'year': 1954, 'title': 'Somewhere Under the Broad Sky'},
#  {'count': 2, 'year': 2012, 'title': 'How to Meet Girls from a Distance'},
#  {'count': 2, 'year': 1983, 'title': 'Flashdance'},
#  {'count': 2, 'year': 2013, 'title': 'Carrie'},
#  {'count': 2, 'year': 2006, 'title': 'First Flight'},
#  {'count': 2, 'year': 2005, 'title': 'Secret Smile'},
#  {'count': 2, 'year': 1976, 'title': 'Barocco'},
#  {'count': 2, 'year': 2015, 'title': 'Terminator Genisys'},
#  {'count': 2, 'year': '2012è', 'title': 'Hit & Miss'},
#  {'count': 2, 'year': 1997, 'title': 'Speed 2: Cruise Control'},
#  {'count': 2, 'year': 2001, 'title': 'Chaos'},
#  {'count': 2, 'year': 1990, 'title': 'La dèsenchantèe'},
#  {'count': 2, 'year': 2011, 'title': 'Saheb Biwi Aur Gangster'},
#  {'count': 2, 'year': 1997, 'title': 'Addicted to Love'},
#  {'count': 2, 'year': 1989, 'title': 'Always'},
#  {'count': 2, 'year': 2005, 'title': 'An American Girl Adventure'},
#  {'count': 2, 'year': 1994, 'title': "Mary Shelley's Frankenstein"},
#  {'count': 2, 'year': 2006, 'title': 'Heaven on Earth'},
#  {'count': 2, 'year': 1998, 'title': 'Glasblèsarns barn'},
#  {'count': 2, 'year': 2000, 'title': "Girls Can't Swim"},
#  {'count': 2, 'year': 1936, 'title': 'The Green Pastures'},
#  {'count': 2, 'year': 2000, 'title': 'Azzurro'},
#  {'count': 2, 'year': 1999, 'title': 'Butterfly'},
#  {'count': 2,
#   'year': 2000,
#   'title': 'Forklift Driver Klaus: The First Day on the Job'},
#  {'count': 2, 'year': 2014, 'title': "Let's Be Cops"},
#  {'count': 2, 'year': 2006, 'title': 'Corporate'},
#  {'count': 2, 'year': 2014, 'title': 'Maya the Bee Movie'},
#  {'count': 2, 'year': 2003, 'title': 'Ghosts of the Abyss'},
#  {'count': 2, 'year': 1992, 'title': 'Stop! Or My Mom Will Shoot'},
#  {'count': 2, 'year': 1978, 'title': 'Newsfront'},
#  {'count': 2, 'year': 2011, 'title': 'The Painting'},
#  {'count': 2, 'year': 2014, 'title': 'Messi'},
#  {'count': 2, 'year': 1944, 'title': 'National Velvet'},
#  {'count': 2, 'year': 2008, 'title': 'The Children'},
#  {'count': 2, 'year': 2013, 'title': 'Percy Jackson: Sea of Monsters'},
#  {'count': 2, 'year': 2002, 'title': 'Shakthi: The Power'},
#  {'count': 2, 'year': 2004, 'title': 'Primer'},
#  {'count': 2, 'year': 2012, 'title': 'Justice League: Doom'},
#  {'count': 2, 'year': 2010, 'title': 'Sacrifice'},
#  {'count': 2, 'year': 2004, 'title': 'Species III'},
#  {'count': 2, 'year': 2001, 'title': 'No Turning Back'},
#  {'count': 2, 'year': 2007, 'title': "A Stranger's Heart"},
#  {'count': 2, 'year': 2002, 'title': 'Flower & Garnet'},
#  {'count': 2, 'year': 1964, 'title': "A Hard Day's Night"},
#  {'count': 2, 'year': 2013, 'title': 'Richard Pryor: Omit the Logic'},
#  {'count': 2, 'year': 1955, 'title': 'The Grand Maneuver'},
#  {'count': 2, 'year': 2010, 'title': 'Khaleja'},
#  {'count': 2, 'year': 1955, 'title': 'The Kentuckian'},
#  {'count': 2, 'year': 2009, 'title': 'Looking for Eric'},
#  {'count': 2, 'year': 2014, 'title': "Marie's Story"},
#  {'count': 2, 'year': 2013, 'title': 'Made in America'},
#  {'count': 2, 'year': 1999, 'title': 'Les convoyeurs attendent'},
#  {'count': 2, 'year': 2013, 'title': 'Like the Wind'},
#  {'count': 2, 'year': 2007, 'title': 'Continental, un film sans fusil'},
#  {'count': 2, 'year': 2009, 'title': 'Boogie'},
#  {'count': 2, 'year': 2009, 'title': 'My Bloody Valentine'},
#  {'count': 2,
#   'year': 1993,
#   'title': 'Thirty Two Short Films About Glenn Gould'},
#  {'count': 2, 'year': 2014, 'title': "Winter's Tale"},
#  {'count': 2, 'year': 2006, 'title': 'Asterix and the Vikings'},
#  {'count': 2, 'year': 2006, 'title': 'Starter for 10'},
#  {'count': 2, 'year': 2006, 'title': "Tuya's Marriage"},
#  {'count': 2, 'year': 1974, 'title': 'The Deluge'},
#  {'count': 2, 'year': 2009, 'title': 'Big River Man'},
#  {'count': 2, 'year': 2002, 'title': 'OT: Our Town'},
#  {'count': 2, 'year': 2006, 'title': '4 Minutes'},
#  {'count': 2, 'year': 1998, 'title': 'Hitman Hart: Wrestling with Shadows'},
#  {'count': 2,
#   'year': 1999,
#   'title': 'Joseph and the Amazing Technicolor Dreamcoat'},
#  {'count': 2, 'year': 2004, 'title': "Love's Enduring Promise"},
#  {'count': 2, 'year': 2000, 'title': 'Tadpole'},
#  {'count': 2, 'year': 1999, 'title': 'Kiss Me in the Rain'},
#  {'count': 2, 'year': 2009, 'title': 'The Velveteen Rabbit'},
#  {'count': 2, 'year': 1996, 'title': 'Never Met Picasso'},
#  {'count': 2,
#   'year': 1997,
#   'title': 'Breaking the Surface: The Greg Louganis Story'},
#  {'count': 2, 'year': 1956, 'title': 'The Ogre of Athens'},
#  {'count': 2, 'year': 1935, 'title': 'Wife! Be Like a Rose!'},
#  {'count': 2, 'year': 2003, 'title': 'Bad Eggs'},
#  {'count': 2, 'year': 2013, 'title': "Nobody's Daughter Haewon"},
#  {'count': 2, 'year': 1971, 'title': 'THX 1138'},
#  {'count': 2, 'year': 1996, 'title': 'Up Close & Personal'},
#  {'count': 2, 'year': 2013, 'title': 'Monica Z'},
#  {'count': 2, 'year': 1958, 'title': 'Love Is My Profession'},
#  {'count': 2, 'year': 2008, 'title': 'John Adams'},
#  {'count': 2, 'year': 2015, 'title': 'Youth'},
#  {'count': 2, 'year': 1994, 'title': 'Lakota Woman: Siege at Wounded Knee'},
#  {'count': 2, 'year': 2012, 'title': 'Elliot Loves'},
#  {'count': 2, 'year': 1999, 'title': 'Best Laid Plans'},
#  {'count': 2, 'year': 1984, 'title': 'Godzilla 1985'},
#  {'count': 2, 'year': 2012, 'title': 'The Last Sentence'},
#  {'count': 2, 'year': 1979, 'title': 'Saint Jack'},
#  {'count': 2, 'year': 1968, 'title': 'Isadora'},
#  {'count': 2, 'year': 2011, 'title': 'Thor'},
#  {'count': 2, 'year': 2011, 'title': 'Melancholia'},
#  {'count': 2, 'year': 1993, 'title': 'Cop & è'},
#  {'count': 2, 'year': 1995, 'title': 'Mother Dao, the Turtlelike'},
#  {'count': 2, 'year': 2008, 'title': 'Afterwards'},
#  {'count': 2, 'year': 2009, 'title': 'The Christmas Party'},
#  {'count': 2, 'year': 2007, 'title': 'Crows Zero'},
#  {'count': 2, 'year': 2004, 'title': 'Addictions and Subtractions'},
#  {'count': 2, 'year': 1961, 'title': 'Gas, Inspector Palmu!'},
#  {'count': 2, 'year': 2011, 'title': 'Kung Fu Panda 2'},
#  {'count': 2, 'year': 2011, 'title': 'The Lost Bladesman'},
#  {'count': 2, 'year': 2015, 'title': 'Ivy'},
#  {'count': 2, 'year': 2002, 'title': 'Year of the Devil'},
#  {'count': 2, 'year': 1977, 'title': 'In the Name of the Pope King'},
#  {'count': 2, 'year': 2014, 'title': 'Big Game'},
#  {'count': 2, 'year': 2013, 'title': 'Joanna'},
#  {'count': 2, 'year': 2014, 'title': 'The Falling'},
#  {'count': 2, 'year': 2004, 'title': 'Bionicle 2: Legends of Metru Nui'},
#  {'count': 2, 'year': 2004, 'title': 'Tony Takitani'},
#  {'count': 2, 'year': 2003, 'title': 'God Is Brazilian'},
#  {'count': 2, 'year': 2004, 'title': 'Saving Face'},
#  {'count': 2, 'year': 1997, 'title': 'Tomorrow Never Dies'},
#  {'count': 2, 'year': 2002, 'title': 'The Settlement'},
#  {'count': 2, 'year': 2006, 'title': 'Hammer & Tickle'},
#  {'count': 2, 'year': 2013, 'title': 'The Identity Theft of Mitch Mustain'},
#  {'count': 2, 'year': 2005, 'title': 'The Dark Hours'},
#  {'count': 2, 'year': 1992, 'title': 'The Player'},
#  {'count': 2, 'year': 2011, 'title': 'Hotel Swooni'},
#  {'count': 2, 'year': 1999, 'title': 'A Slipping-Down Life'},
#  {'count': 2, 'year': 2014, 'title': 'Just Eat It: A Food Waste Story'},
#  {'count': 2, 'year': 1979, 'title': 'Rich Kids'},
#  {'count': 2, 'year': 2004, 'title': 'The Bridge of San Luis Rey'},
#  ...]

# %% [markdown]
# #### Задача 2.2 (1 балл)

# %% [markdown]
# Используя данные, полученные в задаче 2.1, выведите на экран столбчатую диаграмму, показывающую топ-20 наиболее комментируемых фильмов.
# По оси ординат выведите названия этих фильмов (подписи разместите слева диаграммы), по оси абсцисс — количество комментариев.
# Для решения задачи можно использовать любую библиотеку, например, Seaborn или Matplotlib.

# %%
# Ваш код здесь

import matplotlib.pyplot as plt

top_20 = data[:20]

titles = [doc['title'] for doc in top_20]
counts = [doc['count'] for doc in top_20]

plt.barh(titles, counts)
plt.xlabel('Количество комментариев')
plt.ylabel('Название фильма')  
plt.title('Количество комментариев по фильмам')

plt.show()
